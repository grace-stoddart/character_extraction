# %%
### This notebook contains rough code for constructing Latex tables with experimental results

# %%
from tabulate import tabulate
from texttable import Texttable

import latextable
import numpy as np

# %%
import sys
sys.path.append('../src')

from misc import open_dict, get_file_names

# %%
settings = open_dict('../results/ablation_testing/settings_params_from_chosen_each_timeProppLearner_from_allen_short.p')

# %% [markdown]
# ### Classifier Results

# %%
## #create dict arranged differently: datast, sampling strategy, experiment, acc/prec/recall/f1

datasetNames = list(settings.keys())
print(datasetNames)
experimentNames = list(settings[datasetNames[0]]['results'].keys())
print(experimentNames)
samplingStrategies = list(settings[datasetNames[0]]['results'][experimentNames[0]].keys())
print(samplingStrategies)
measures = list(settings[datasetNames[0]]['results'][experimentNames[0]][samplingStrategies[0]].keys())
print(measures)
# Out:
# ['ProppLearner_from_gold', 'ProppLearner_from_allen', 'ProppLearner_from_heads_only', 'LitBank_from_gold', 'LitBank_from_allen', 'CEN_from_allen', 'CEN_from_heads_only', 'ProppLearner_from_allen_short']
# ['original features', 'index features', 'CoreNLP', 'additional features', 'additional features plus CN']
# ['normal', 'over', 'over_under']
# ['accuracy', 'precision', 'recall', 'f1']

# %%
resultsByName = {}

for datasetName in datasetNames:

    # if datasetName in ['ProppLearner_from_allen_short']:
    #     continue
    
    resultsByName[datasetName] = {}


    for samplingStrategyName in samplingStrategies:
        resultsByName[datasetName][samplingStrategyName] = {}

        for experimentName in experimentNames:
            resultsByName[datasetName][samplingStrategyName][experimentName] = {}

            for measureName in measures:
                resultsByName[datasetName][samplingStrategyName][experimentName][measureName] = 0

# %%
for datasetName, dataset in settings.items():
    # if datasetName in ['ProppLearner_from_allen_short']:
    #     continue
    
    results = dataset['results']
    for experimentName, experiment in results.items():
        for samplingStrategyName, samplingStrategy in experiment.items():
            for measureName, measure in samplingStrategy.items():
                resultsByName[datasetName][samplingStrategyName][experimentName][measureName] = measure

# %% [markdown]
# #### Table 1 (Original ALlenNLP vs using CoreNLP)

# %%
# rows = [['','Normal', 'Over', 'Over Under', 'Normal', 'Over', 'Over Under']]
# for expName, exp in settings.items():

#     row = [expName]

#     for resName in ['original features', 'CoreNLP']:

#         for key, val in exp['results'][resName].items():
#             row.append('$' + str(val['avg']) + '$')
        
#     rows.append(row)

rows = [['Sampling method','Accuracy', 'Precision', 'Recall','F-score','Accuracy', 'Precision', 'Recall','F-score']]

for datasetName, dataset in resultsByName.items():

    for samplingStratName, samplingStrat in dataset.items():

        row = ['$' + datasetName + ' ' + samplingStratName + '$']
        count = 0

        while count <= 1:
            for expName, exp in samplingStrat.items():
                
                if count == 0:

                    if expName == 'CoreNLP':

                        for measureName, res in exp.items():
                            row.append('$' +  str(res['avg'])  + '$')

                        count += 1
                
                elif count == 1:
                    if expName == 'original features':
                        for measureName, res in exp.items():
                            row.append('$' +  str(res['avg'])  + '$')

                        count += 1

                

        rows.append(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25208\1266846692.py in <module>
#      28
#      29                         for measureName, res in exp.items():
# ---> 30                             row.append('$' +  str(res['avg'])  + '$')
#      31
#      32                         count += 1
#
# TypeError: 'int' object is not subscriptable

# %%
capt = 'A comparison between the the classification model in the original approach when features are constructed using statistical methods (CoreNLP), and the same model when features are constructed using methods based on PTLMs (AllenNLP).'

table = Texttable()
table.set_cols_align(["c"] * len(rows[0]))
table.set_deco(Texttable.HEADER | Texttable.VLINES)
table.add_rows(rows)

print('\nTexttable Table')
print(table.draw())

print('\nTexttable Latex:')
print(latextable.draw_latex(table, caption=capt))
# Out:
# Texttable Table
# Samplin | Accurac | Precis | Recall | F-scor | Accura | Precis | Recall | F-scor
#    g    |    y    |  ion   |        |   e    |   cy   |  ion   |        |   e
# method  |         |        |        |        |        |        |        |
# ========+=========+========+========+========+========+========+========+=======
# $ProppL | $0.96$  | $0.69$ | $0.91$ | $0.78$ | $0.97$ | $0.74$ | $0.95$ | $0.83$
# earner_ |         |        |        |        |        |        |        |
# from_go |         |        |        |        |        |        |        |
#   ld    |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $ProppL | $0.97$  | $0.81$ | $0.8$  | $0.8$  | $0.97$ | $0.75$ | $0.94$ | $0.83$
# earner_ |         |        |        |        |        |        |        |
# from_go |         |        |        |        |        |        |        |
#   ld    |         |        |        |        |        |        |        |
#  over$  |         |        |        |        |        |        |        |
# $ProppL | $0.97$  | $0.81$ | $0.8$  | $0.8$  | $0.98$ | $0.92$ | $0.76$ | $0.83$
# earner_ |         |        |        |        |        |        |        |
# from_go |         |        |        |        |        |        |        |
# ld over |         |        |        |        |        |        |        |
# _under$ |         |        |        |        |        |        |        |
# $ProppL | $0.83$  | $0.61$ | $0.88$ | $0.72$ | $0.85$ | $0.63$ | $0.85$ | $0.72$
# earner_ |         |        |        |        |        |        |        |
# from_al |         |        |        |        |        |        |        |
#   len   |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $ProppL | $0.85$  | $0.64$ | $0.84$ | $0.73$ | $0.86$ | $0.66$ | $0.82$ | $0.73$
# earner_ |         |        |        |        |        |        |        |
# from_al |         |        |        |        |        |        |        |
#   len   |         |        |        |        |        |        |        |
#  over$  |         |        |        |        |        |        |        |
# $ProppL | $0.85$  | $0.64$ | $0.84$ | $0.72$ | $0.84$ | $0.63$ | $0.85$ | $0.72$
# earner_ |         |        |        |        |        |        |        |
# from_al |         |        |        |        |        |        |        |
# len ove |         |        |        |        |        |        |        |
# r_under |         |        |        |        |        |        |        |
#    $    |         |        |        |        |        |        |        |
# $ProppL | $0.88$  | $0.76$ | $0.85$ | $0.8$  | $0.87$ | $0.77$ | $0.83$ | $0.8$
# earner_ |         |        |        |        |        |        |        |
# from_he |         |        |        |        |        |        |        |
# ads_onl |         |        |        |        |        |        |        |
#    y    |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $ProppL | $0.88$  | $0.76$ | $0.84$ | $0.8$  | $0.88$ | $0.78$ | $0.83$ | $0.8$
# earner_ |         |        |        |        |        |        |        |
# from_he |         |        |        |        |        |        |        |
# ads_onl |         |        |        |        |        |        |        |
# y over$ |         |        |        |        |        |        |        |
# $ProppL | $0.88$  | $0.76$ | $0.85$ | $0.8$  | $0.88$ | $0.77$ | $0.82$ | $0.8$
# earner_ |         |        |        |        |        |        |        |
# from_he |         |        |        |        |        |        |        |
# ads_onl |         |        |        |        |        |        |        |
# y over_ |         |        |        |        |        |        |        |
# under$  |         |        |        |        |        |        |        |
# $LitBan | $0.95$  | $0.16$ | $0.24$ | $0.18$ | $0.95$ | $0.21$ | $0.45$ | $0.28$
# k_from_ |         |        |        |        |        |        |        |
#  gold   |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $LitBan | $0.97$  | $0.42$ | $0.41$ | $0.4$  | $0.97$ | $0.43$ | $0.42$ | $0.42$
# k_from_ |         |        |        |        |        |        |        |
#  gold   |         |        |        |        |        |        |        |
#  over$  |         |        |        |        |        |        |        |
# $LitBan | $0.97$  | $0.42$ | $0.41$ | $0.4$  | $0.97$ | $0.45$ | $0.42$ | $0.41$
# k_from_ |         |        |        |        |        |        |        |
# gold ov |         |        |        |        |        |        |        |
# er_unde |         |        |        |        |        |        |        |
#   r$    |         |        |        |        |        |        |        |
# $LitBan | $0.92$  | $0.13$ | $0.25$ | $0.17$ | $0.93$ | $0.24$ | $0.42$ | $0.28$
# k_from_ |         |        |        |        |        |        |        |
#  allen  |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $LitBan | $0.95$  | $0.39$ | $0.44$ | $0.4$  | $0.95$ | $0.39$ | $0.42$ | $0.39$
# k_from_ |         |        |        |        |        |        |        |
#  allen  |         |        |        |        |        |        |        |
#  over$  |         |        |        |        |        |        |        |
# $LitBan | $0.95$  | $0.4$  | $0.44$ | $0.4$  | $0.95$ | $0.4$  | $0.42$ | $0.39$
# k_from_ |         |        |        |        |        |        |        |
# allen o |         |        |        |        |        |        |        |
# ver_und |         |        |        |        |        |        |        |
#   er$   |         |        |        |        |        |        |        |
# $CEN_fr | $0.82$  | $0.43$ | $0.8$  | $0.55$ | $0.85$ | $0.49$ | $0.75$ | $0.59$
# om_alle |         |        |        |        |        |        |        |
#    n    |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $CEN_fr | $0.84$  | $0.47$ | $0.72$ | $0.56$ | $0.84$ | $0.48$ | $0.82$ | $0.6$
# om_alle |         |        |        |        |        |        |        |
# n over$ |         |        |        |        |        |        |        |
# $CEN_fr |  $0.8$  | $0.4$  | $0.85$ | $0.55$ | $0.85$ | $0.49$ | $0.81$ | $0.6$
# om_alle |         |        |        |        |        |        |        |
# n over_ |         |        |        |        |        |        |        |
# under$  |         |        |        |        |        |        |        |
# $CEN_fr | $0.97$  | $0.44$ | $0.96$ | $0.6$  | $0.97$ | $0.45$ | $0.95$ | $0.61$
# om_head |         |        |        |        |        |        |        |
# s_only  |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $CEN_fr | $0.97$  | $0.5$  | $0.94$ | $0.65$ | $0.97$ | $0.45$ | $0.95$ | $0.62$
# om_head |         |        |        |        |        |        |        |
# s_only  |         |        |        |        |        |        |        |
#  over$  |         |        |        |        |        |        |        |
# $CEN_fr | $0.97$  | $0.49$ | $0.94$ | $0.65$ | $0.97$ | $0.45$ | $0.95$ | $0.61$
# om_head |         |        |        |        |        |        |        |
# s_only  |         |        |        |        |        |        |        |
# over_un |         |        |        |        |        |        |        |
#  der$   |         |        |        |        |        |        |        |
#
# Texttable Latex:
# \begin{table}
# 	\begin{center}
# 		\begin{tabular}{c|c|c|c|c|c|c|c|c}
# 			Sampling method & Accuracy & Precision & Recall & F-score & Accuracy & Precision & Recall & F-score \\
# 			\hline
# 			$ProppLearner_from_gold normal$ & $0.96$ & $0.69$ & $0.91$ & $0.78$ & $0.97$ & $0.74$ & $0.95$ & $0.83$ \\
# 			$ProppLearner_from_gold over$ & $0.97$ & $0.81$ & $0.8$ & $0.8$ & $0.97$ & $0.75$ & $0.94$ & $0.83$ \\
# 			$ProppLearner_from_gold over_under$ & $0.97$ & $0.81$ & $0.8$ & $0.8$ & $0.98$ & $0.92$ & $0.76$ & $0.83$ \\
# 			$ProppLearner_from_allen normal$ & $0.83$ & $0.61$ & $0.88$ & $0.72$ & $0.85$ & $0.63$ & $0.85$ & $0.72$ \\
# 			$ProppLearner_from_allen over$ & $0.85$ & $0.64$ & $0.84$ & $0.73$ & $0.86$ & $0.66$ & $0.82$ & $0.73$ \\
# 			$ProppLearner_from_allen over_under$ & $0.85$ & $0.64$ & $0.84$ & $0.72$ & $0.84$ & $0.63$ & $0.85$ & $0.72$ \\
# 			$ProppLearner_from_heads_only normal$ & $0.88$ & $0.76$ & $0.85$ & $0.8$ & $0.87$ & $0.77$ & $0.83$ & $0.8$ \\
# 			$ProppLearner_from_heads_only over$ & $0.88$ & $0.76$ & $0.84$ & $0.8$ & $0.88$ & $0.78$ & $0.83$ & $0.8$ \\
# 			$ProppLearner_from_heads_only over_under$ & $0.88$ & $0.76$ & $0.85$ & $0.8$ & $0.88$ & $0.77$ & $0.82$ & $0.8$ \\
# 			$LitBank_from_gold normal$ & $0.95$ & $0.16$ & $0.24$ & $0.18$ & $0.95$ & $0.21$ & $0.45$ & $0.28$ \\
# 			$LitBank_from_gold over$ & $0.97$ & $0.42$ & $0.41$ & $0.4$ & $0.97$ & $0.43$ & $0.42$ & $0.42$ \\
# 			$LitBank_from_gold over_under$ & $0.97$ & $0.42$ & $0.41$ & $0.4$ & $0.97$ & $0.45$ & $0.42$ & $0.41$ \\
# 			$LitBank_from_allen normal$ & $0.92$ & $0.13$ & $0.25$ & $0.17$ & $0.93$ & $0.24$ & $0.42$ & $0.28$ \\
# 			$LitBank_from_allen over$ & $0.95$ & $0.39$ & $0.44$ & $0.4$ & $0.95$ & $0.39$ & $0.42$ & $0.39$ \\
# 			$LitBank_from_allen over_under$ & $0.95$ & $0.4$ & $0.44$ & $0.4$ & $0.95$ & $0.4$ & $0.42$ & $0.39$ \\
# 			$CEN_from_allen normal$ & $0.82$ & $0.43$ & $0.8$ & $0.55$ & $0.85$ & $0.49$ & $0.75$ & $0.59$ \\
# 			$CEN_from_allen over$ & $0.84$ & $0.47$ & $0.72$ & $0.56$ & $0.84$ & $0.48$ & $0.82$ & $0.6$ \\
# 			$CEN_from_allen over_under$ & $0.8$ & $0.4$ & $0.85$ & $0.55$ & $0.85$ & $0.49$ & $0.81$ & $0.6$ \\
# 			$CEN_from_heads_only normal$ & $0.97$ & $0.44$ & $0.96$ & $0.6$ & $0.97$ & $0.45$ & $0.95$ & $0.61$ \\
# 			$CEN_from_heads_only over$ & $0.97$ & $0.5$ & $0.94$ & $0.65$ & $0.97$ & $0.45$ & $0.95$ & $0.62$ \\
# 			$CEN_from_heads_only over_under$ & $0.97$ & $0.49$ & $0.94$ & $0.65$ & $0.97$ & $0.45$ & $0.95$ & $0.61$ \\
# 		\end{tabular}
# 	\end{center}
# 	\caption{A comparison between the the classification model in the original approach when features are constructed using statistical methods (CoreNLP), and the same model when features are constructed using methods based on PTLMs (AllenNLP).}
# \end{table}

# %%
capt = 'A comparison between the the classification model in the original approach when features are constructed using statistical methods (CoreNLP), and the same model when features are constructed using methods based on PTLMs (AllenNLP).'

table = Texttable()
table.set_cols_align(["c"] * len(rows[0]))
table.set_deco(Texttable.HEADER | Texttable.VLINES)
table.add_rows(rows)

print('\nTexttable Table')
print(table.draw())

print('\nTexttable Latex:')
print(latextable.draw_latex(table, caption=capt))
# Out:
# Texttable Table
# Samplin | Accurac | Precis | Recall | F-scor | Accura | Precis | Recall | F-scor
#    g    |    y    |  ion   |        |   e    |   cy   |  ion   |        |   e
# method  |         |        |        |        |        |        |        |
# ========+=========+========+========+========+========+========+========+=======
# $ProppL | $0.97$  | $0.74$ | $0.95$ | $0.83$ | $0.96$ | $0.69$ | $0.91$ | $0.78$
# earner_ |         |        |        |        |        |        |        |
# from_go |         |        |        |        |        |        |        |
#   ld    |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $ProppL | $0.97$  | $0.75$ | $0.94$ | $0.83$ | $0.97$ | $0.81$ | $0.8$  | $0.8$
# earner_ |         |        |        |        |        |        |        |
# from_go |         |        |        |        |        |        |        |
#   ld    |         |        |        |        |        |        |        |
#  over$  |         |        |        |        |        |        |        |
# $ProppL | $0.98$  | $0.92$ | $0.76$ | $0.83$ | $0.97$ | $0.81$ | $0.8$  | $0.8$
# earner_ |         |        |        |        |        |        |        |
# from_go |         |        |        |        |        |        |        |
# ld over |         |        |        |        |        |        |        |
# _under$ |         |        |        |        |        |        |        |
# $ProppL | $0.85$  | $0.63$ | $0.85$ | $0.72$ | $0.83$ | $0.61$ | $0.88$ | $0.72$
# earner_ |         |        |        |        |        |        |        |
# from_al |         |        |        |        |        |        |        |
#   len   |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $ProppL | $0.86$  | $0.66$ | $0.82$ | $0.73$ | $0.85$ | $0.64$ | $0.84$ | $0.73$
# earner_ |         |        |        |        |        |        |        |
# from_al |         |        |        |        |        |        |        |
#   len   |         |        |        |        |        |        |        |
#  over$  |         |        |        |        |        |        |        |
# $ProppL | $0.84$  | $0.63$ | $0.85$ | $0.72$ | $0.85$ | $0.64$ | $0.84$ | $0.72$
# earner_ |         |        |        |        |        |        |        |
# from_al |         |        |        |        |        |        |        |
# len ove |         |        |        |        |        |        |        |
# r_under |         |        |        |        |        |        |        |
#    $    |         |        |        |        |        |        |        |
# $ProppL | $0.87$  | $0.77$ | $0.83$ | $0.8$  | $0.88$ | $0.76$ | $0.85$ | $0.8$
# earner_ |         |        |        |        |        |        |        |
# from_he |         |        |        |        |        |        |        |
# ads_onl |         |        |        |        |        |        |        |
#    y    |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $ProppL | $0.88$  | $0.78$ | $0.83$ | $0.8$  | $0.88$ | $0.76$ | $0.84$ | $0.8$
# earner_ |         |        |        |        |        |        |        |
# from_he |         |        |        |        |        |        |        |
# ads_onl |         |        |        |        |        |        |        |
# y over$ |         |        |        |        |        |        |        |
# $ProppL | $0.88$  | $0.77$ | $0.82$ | $0.8$  | $0.88$ | $0.76$ | $0.85$ | $0.8$
# earner_ |         |        |        |        |        |        |        |
# from_he |         |        |        |        |        |        |        |
# ads_onl |         |        |        |        |        |        |        |
# y over_ |         |        |        |        |        |        |        |
# under$  |         |        |        |        |        |        |        |
# $LitBan | $0.95$  | $0.21$ | $0.45$ | $0.28$ | $0.95$ | $0.16$ | $0.24$ | $0.18$
# k_from_ |         |        |        |        |        |        |        |
#  gold   |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $LitBan | $0.97$  | $0.43$ | $0.42$ | $0.42$ | $0.97$ | $0.42$ | $0.41$ | $0.4$
# k_from_ |         |        |        |        |        |        |        |
#  gold   |         |        |        |        |        |        |        |
#  over$  |         |        |        |        |        |        |        |
# $LitBan | $0.97$  | $0.45$ | $0.42$ | $0.41$ | $0.97$ | $0.42$ | $0.41$ | $0.4$
# k_from_ |         |        |        |        |        |        |        |
# gold ov |         |        |        |        |        |        |        |
# er_unde |         |        |        |        |        |        |        |
#   r$    |         |        |        |        |        |        |        |
# $LitBan | $0.93$  | $0.24$ | $0.42$ | $0.28$ | $0.92$ | $0.13$ | $0.25$ | $0.17$
# k_from_ |         |        |        |        |        |        |        |
#  allen  |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $LitBan | $0.95$  | $0.39$ | $0.42$ | $0.39$ | $0.95$ | $0.39$ | $0.44$ | $0.4$
# k_from_ |         |        |        |        |        |        |        |
#  allen  |         |        |        |        |        |        |        |
#  over$  |         |        |        |        |        |        |        |
# $LitBan | $0.95$  | $0.4$  | $0.42$ | $0.39$ | $0.95$ | $0.4$  | $0.44$ | $0.4$
# k_from_ |         |        |        |        |        |        |        |
# allen o |         |        |        |        |        |        |        |
# ver_und |         |        |        |        |        |        |        |
#   er$   |         |        |        |        |        |        |        |
# $CEN_fr | $0.85$  | $0.49$ | $0.75$ | $0.59$ | $0.82$ | $0.43$ | $0.8$  | $0.55$
# om_alle |         |        |        |        |        |        |        |
#    n    |         |        |        |        |        |        |        |
# normal$ |         |        |        |        |        |        |        |
# $CEN_fr | $0.84$  | $0.48$ | $0.82$ | $0.6$  | $0.84$ | $0.47$ | $0.72$ | $0.56$
# om_alle |         |        |        |        |        |        |        |
# n over$ |         |        |        |        |        |        |        |
# $CEN_fr | $0.85$  | $0.49$ | $0.81$ | $0.6$  | $0.8$  | $0.4$  | $0.85$ | $0.55$
# om_alle |         |        |        |        |        |        |        |
# n over_ |         |        |        |        |        |        |        |
# under$  |         |        |        |        |        |        |        |
#
# Texttable Latex:
# \begin{table}
# 	\begin{center}
# 		\begin{tabular}{c|c|c|c|c|c|c|c|c}
# 			Sampling method & Accuracy & Precision & Recall & F-score & Accuracy & Precision & Recall & F-score \\
# 			\hline
# 			$ProppLearner_from_gold normal$ & $0.97$ & $0.74$ & $0.95$ & $0.83$ & $0.96$ & $0.69$ & $0.91$ & $0.78$ \\
# 			$ProppLearner_from_gold over$ & $0.97$ & $0.75$ & $0.94$ & $0.83$ & $0.97$ & $0.81$ & $0.8$ & $0.8$ \\
# 			$ProppLearner_from_gold over_under$ & $0.98$ & $0.92$ & $0.76$ & $0.83$ & $0.97$ & $0.81$ & $0.8$ & $0.8$ \\
# 			$ProppLearner_from_allen normal$ & $0.85$ & $0.63$ & $0.85$ & $0.72$ & $0.83$ & $0.61$ & $0.88$ & $0.72$ \\
# 			$ProppLearner_from_allen over$ & $0.86$ & $0.66$ & $0.82$ & $0.73$ & $0.85$ & $0.64$ & $0.84$ & $0.73$ \\
# 			$ProppLearner_from_allen over_under$ & $0.84$ & $0.63$ & $0.85$ & $0.72$ & $0.85$ & $0.64$ & $0.84$ & $0.72$ \\
# 			$ProppLearner_from_heads_only normal$ & $0.87$ & $0.77$ & $0.83$ & $0.8$ & $0.88$ & $0.76$ & $0.85$ & $0.8$ \\
# 			$ProppLearner_from_heads_only over$ & $0.88$ & $0.78$ & $0.83$ & $0.8$ & $0.88$ & $0.76$ & $0.84$ & $0.8$ \\
# 			$ProppLearner_from_heads_only over_under$ & $0.88$ & $0.77$ & $0.82$ & $0.8$ & $0.88$ & $0.76$ & $0.85$ & $0.8$ \\
# 			$LitBank_from_gold normal$ & $0.95$ & $0.21$ & $0.45$ & $0.28$ & $0.95$ & $0.16$ & $0.24$ & $0.18$ \\
# 			$LitBank_from_gold over$ & $0.97$ & $0.43$ & $0.42$ & $0.42$ & $0.97$ & $0.42$ & $0.41$ & $0.4$ \\
# 			$LitBank_from_gold over_under$ & $0.97$ & $0.45$ & $0.42$ & $0.41$ & $0.97$ & $0.42$ & $0.41$ & $0.4$ \\
# 			$LitBank_from_allen normal$ & $0.93$ & $0.24$ & $0.42$ & $0.28$ & $0.92$ & $0.13$ & $0.25$ & $0.17$ \\
# 			$LitBank_from_allen over$ & $0.95$ & $0.39$ & $0.42$ & $0.39$ & $0.95$ & $0.39$ & $0.44$ & $0.4$ \\
# 			$LitBank_from_allen over_under$ & $0.95$ & $0.4$ & $0.42$ & $0.39$ & $0.95$ & $0.4$ & $0.44$ & $0.4$ \\
# 			$CEN_from_allen normal$ & $0.85$ & $0.49$ & $0.75$ & $0.59$ & $0.82$ & $0.43$ & $0.8$ & $0.55$ \\
# 			$CEN_from_allen over$ & $0.84$ & $0.48$ & $0.82$ & $0.6$ & $0.84$ & $0.47$ & $0.72$ & $0.56$ \\
# 			$CEN_from_allen over_under$ & $0.85$ & $0.49$ & $0.81$ & $0.6$ & $0.8$ & $0.4$ & $0.85$ & $0.55$ \\
# 		\end{tabular}
# 	\end{center}
# 	\caption{A comparison between the the classification model in the original approach when features are constructed using statistical methods (CoreNLP), and the same model when features are constructed using methods based on PTLMs (AllenNLP).}
# \end{table}

# %% [markdown]
# #### Table 2 (Indexes)

# %%
# rows = [['','Normal', 'Over', 'Over Under']]
# for expName, exp in settings.items():

#     if exp['OrigOnly']:
#         continue
    
#     row = [expName]

#     for resName in ['index features']:

#         for key, val in exp['results'][resName].items():
#             row.append('$' + str(val['avg']) + '$')
        
#     rows.append(row)


rows = [['Sampling method','Accuracy', 'Precision', 'Recall','F-score']]

for datasetName, dataset in resultsByName.items():

    if settings[datasetName]['OrigOnly']:
        continue

    for samplingStratName, samplingStrat in dataset.items():

        row = ['$' + datasetName + ' ' + samplingStratName + '$']

        for expName, exp in samplingStrat.items():
        
            if expName == 'index features':

                for measureName, res in exp.items():
                    row.append('$' +  str(res['avg'])  + '$')

        rows.append(row)

# %%
table = Texttable()
table.set_cols_align(["c"] * len(rows[0]))
table.set_deco(Texttable.HEADER | Texttable.VLINES)
table.add_rows(rows)

print('\nTexttable Table')
print(table.draw())

print('\nTexttable Latex:')
print(latextable.draw_latex(table, caption="F-Scores for the classification model using Index features."))
# Out:
# Texttable Table
#           Sampling method            | Accuracy | Precision | Recall | F-score
# =====================================+==========+===========+========+========
#   $ProppLearner_from_gold normal$    |  $0.97$  |  $0.71$   | $0.95$ | $0.81$
#    $ProppLearner_from_gold over$     |  $0.97$  |  $0.77$   | $0.95$ | $0.85$
# $ProppLearner_from_gold over_under$  |  $0.97$  |   $0.8$   | $0.91$ | $0.85$
#   $ProppLearner_from_allen normal$   |  $0.83$  |  $0.59$   | $0.87$ | $0.71$
#    $ProppLearner_from_allen over$    |  $0.85$  |  $0.65$   | $0.82$ | $0.72$
# $ProppLearner_from_allen over_under$ |  $0.85$  |  $0.65$   | $0.81$ | $0.72$
#      $LitBank_from_gold normal$      |  $0.93$  |  $0.22$   | $0.73$ | $0.34$
#       $LitBank_from_gold over$       |  $0.96$  |  $0.33$   | $0.62$ | $0.42$
#    $LitBank_from_gold over_under$    |  $0.96$  |  $0.34$   | $0.62$ | $0.44$
#     $LitBank_from_allen normal$      |  $0.93$  |  $0.32$   | $0.72$ | $0.43$
#      $LitBank_from_allen over$       |  $0.95$  |  $0.39$   | $0.55$ | $0.45$
#   $LitBank_from_allen over_under$    |  $0.94$  |  $0.35$   | $0.66$ | $0.46$
#       $CEN_from_allen normal$        |  $0.86$  |  $0.51$   | $0.78$ | $0.61$
#        $CEN_from_allen over$         |  $0.91$  |  $0.75$   | $0.55$ | $0.62$
#     $CEN_from_allen over_under$      |  $0.87$  |  $0.55$   | $0.72$ | $0.62$
#
# Texttable Latex:
# \begin{table}
# 	\begin{center}
# 		\begin{tabular}{c|c|c|c|c}
# 			Sampling method & Accuracy & Precision & Recall & F-score \\
# 			\hline
# 			$ProppLearner_from_gold normal$ & $0.97$ & $0.71$ & $0.95$ & $0.81$ \\
# 			$ProppLearner_from_gold over$ & $0.97$ & $0.77$ & $0.95$ & $0.85$ \\
# 			$ProppLearner_from_gold over_under$ & $0.97$ & $0.8$ & $0.91$ & $0.85$ \\
# 			$ProppLearner_from_allen normal$ & $0.83$ & $0.59$ & $0.87$ & $0.71$ \\
# 			$ProppLearner_from_allen over$ & $0.85$ & $0.65$ & $0.82$ & $0.72$ \\
# 			$ProppLearner_from_allen over_under$ & $0.85$ & $0.65$ & $0.81$ & $0.72$ \\
# 			$LitBank_from_gold normal$ & $0.93$ & $0.22$ & $0.73$ & $0.34$ \\
# 			$LitBank_from_gold over$ & $0.96$ & $0.33$ & $0.62$ & $0.42$ \\
# 			$LitBank_from_gold over_under$ & $0.96$ & $0.34$ & $0.62$ & $0.44$ \\
# 			$LitBank_from_allen normal$ & $0.93$ & $0.32$ & $0.72$ & $0.43$ \\
# 			$LitBank_from_allen over$ & $0.95$ & $0.39$ & $0.55$ & $0.45$ \\
# 			$LitBank_from_allen over_under$ & $0.94$ & $0.35$ & $0.66$ & $0.46$ \\
# 			$CEN_from_allen normal$ & $0.86$ & $0.51$ & $0.78$ & $0.61$ \\
# 			$CEN_from_allen over$ & $0.91$ & $0.75$ & $0.55$ & $0.62$ \\
# 			$CEN_from_allen over_under$ & $0.87$ & $0.55$ & $0.72$ & $0.62$ \\
# 		\end{tabular}
# 	\end{center}
# 	\caption{F-Scores for the classification model using Index features.}
# \end{table}

# %% [markdown]
# #### Table 2 (Additional Features)

# %%
# rows = [['','Normal', 'Over', 'Over Under']]
# for expName, exp in settings.items():

#     if exp['OrigOnly']:
#         continue
    
#     row = [expName]

#     for resName in ['additional features']:

#         for key, val in exp['results'][resName].items():
#             row.append('$' + str(val['avg']) + '$')
        
#     rows.append(row)



rows = [['Sampling method','Accuracy', 'Precision', 'Recall','F-score']]

for datasetName, dataset in resultsByName.items():

    if settings[datasetName]['OrigOnly']:
        continue

    for samplingStratName, samplingStrat in dataset.items():

        row = ['$' + datasetName + ' ' + samplingStratName + '$']

        for expName, exp in samplingStrat.items():
        
            if expName == 'additional features':

                for measureName, res in exp.items():
                    row.append('$' +  str(res['avg'])  + '$')

        rows.append(row)

# %%
table = Texttable()
table.set_cols_align(["c"] * len(rows[0]))
table.set_deco(Texttable.HEADER | Texttable.VLINES)
table.add_rows(rows)

print('\nTexttable Table')
print(table.draw())

print('\nTexttable Latex:')
print(latextable.draw_latex(table, caption="F-Scores for the classification model using Index features, the quotation feature and the dispersion feature."))
# Out:
# Texttable Table
#           Sampling method            | Accuracy | Precision | Recall | F-score
# =====================================+==========+===========+========+========
#   $ProppLearner_from_gold normal$    |  $0.97$  |  $0.79$   | $0.92$ | $0.85$
#    $ProppLearner_from_gold over$     |  $0.97$  |   $0.8$   | $0.92$ | $0.85$
# $ProppLearner_from_gold over_under$  |  $0.97$  |  $0.79$   | $0.92$ | $0.84$
#   $ProppLearner_from_allen normal$   |  $0.84$  |  $0.62$   | $0.84$ | $0.71$
#    $ProppLearner_from_allen over$    |  $0.85$  |  $0.65$   | $0.82$ | $0.72$
# $ProppLearner_from_allen over_under$ |  $0.85$  |  $0.65$   | $0.81$ | $0.72$
#      $LitBank_from_gold normal$      |  $0.93$  |  $0.22$   | $0.7$  | $0.34$
#       $LitBank_from_gold over$       |  $0.96$  |  $0.32$   | $0.62$ | $0.41$
#    $LitBank_from_gold over_under$    |  $0.95$  |  $0.29$   | $0.77$ | $0.42$
#     $LitBank_from_allen normal$      |  $0.94$  |  $0.32$   | $0.49$ | $0.38$
#      $LitBank_from_allen over$       |  $0.92$  |   $0.3$   | $0.79$ | $0.43$
#   $LitBank_from_allen over_under$    |  $0.92$  |   $0.3$   | $0.8$  | $0.44$
#       $CEN_from_allen normal$        |  $0.86$  |  $0.51$   | $0.78$ | $0.61$
#        $CEN_from_allen over$         |  $0.91$  |  $0.77$   | $0.54$ | $0.63$
#     $CEN_from_allen over_under$      |  $0.87$  |  $0.54$   | $0.73$ | $0.62$
#
# Texttable Latex:
# \begin{table}
# 	\begin{center}
# 		\begin{tabular}{c|c|c|c|c}
# 			Sampling method & Accuracy & Precision & Recall & F-score \\
# 			\hline
# 			$ProppLearner_from_gold normal$ & $0.97$ & $0.79$ & $0.92$ & $0.85$ \\
# 			$ProppLearner_from_gold over$ & $0.97$ & $0.8$ & $0.92$ & $0.85$ \\
# 			$ProppLearner_from_gold over_under$ & $0.97$ & $0.79$ & $0.92$ & $0.84$ \\
# 			$ProppLearner_from_allen normal$ & $0.84$ & $0.62$ & $0.84$ & $0.71$ \\
# 			$ProppLearner_from_allen over$ & $0.85$ & $0.65$ & $0.82$ & $0.72$ \\
# 			$ProppLearner_from_allen over_under$ & $0.85$ & $0.65$ & $0.81$ & $0.72$ \\
# 			$LitBank_from_gold normal$ & $0.93$ & $0.22$ & $0.7$ & $0.34$ \\
# 			$LitBank_from_gold over$ & $0.96$ & $0.32$ & $0.62$ & $0.41$ \\
# 			$LitBank_from_gold over_under$ & $0.95$ & $0.29$ & $0.77$ & $0.42$ \\
# 			$LitBank_from_allen normal$ & $0.94$ & $0.32$ & $0.49$ & $0.38$ \\
# 			$LitBank_from_allen over$ & $0.92$ & $0.3$ & $0.79$ & $0.43$ \\
# 			$LitBank_from_allen over_under$ & $0.92$ & $0.3$ & $0.8$ & $0.44$ \\
# 			$CEN_from_allen normal$ & $0.86$ & $0.51$ & $0.78$ & $0.61$ \\
# 			$CEN_from_allen over$ & $0.91$ & $0.77$ & $0.54$ & $0.63$ \\
# 			$CEN_from_allen over_under$ & $0.87$ & $0.54$ & $0.73$ & $0.62$ \\
# 		\end{tabular}
# 	\end{center}
# 	\caption{F-Scores for the classification model using Index features, the quotation feature and the dispersion feature.}
# \end{table}

# %% [markdown]
# #### Table 4 (15 stories ProppLearner Allen)

# %%
rows = [['Sampling method','Accuracy', 'Precision', 'Recall','F-score']]

for datasetName, dataset in resultsByName.items():

    if settings[datasetName]['OrigOnly']:
        continue

    for samplingStratName, samplingStrat in dataset.items():

        row = ['$' + datasetName + ' ' + samplingStratName + '$']

        for expName, exp in samplingStrat.items():
        
            if expName == 'additional features':

                for measureName, res in exp.items():
                    row.append('$' +  str(res['avg'])  + '$')

        rows.append(row)

# %%
resultsByName['ProppLearner_from_allen_short']
# Out:
# {'normal': {'original features': {'accuracy': {'avg': 0.85,
#     'all': array([0.80176211, 0.86784141, 0.8061674 , 0.85022026, 0.83700441,
#            0.85462555, 0.84955752, 0.84955752, 0.87610619, 0.84955752,
#            0.84140969, 0.81938326, 0.88105727, 0.84581498, 0.83700441,
#            0.86343612, 0.80088496, 0.85840708, 0.86725664, 0.84955752,
#            0.82378855, 0.86784141, 0.86343612, 0.85022026, 0.86343612,
#            0.87665198, 0.84070796, 0.84955752, 0.82300885, 0.81415929,
#            0.85022026, 0.8061674 , 0.87665198, 0.81057269, 0.8722467 ,
#            0.82819383, 0.90265487, 0.86725664, 0.86283186, 0.84513274,
#            0.82378855, 0.86343612, 0.85462555, 0.77973568, 0.88105727,
#            0.85022026, 0.84955752, 0.85840708, 0.86283186, 0.85840708,
#            0.85022026, 0.85022026, 0.84140969, 0.84581498, 0.84140969,
#            0.72413793, 0.78688525, 0.67213115, 0.72727273, 0.76106195,
#            0.71544715, 0.72727273, 0.64912281, 0.73873874, 0.69565217,
#            0.64285714, 0.76271186, 0.70689655, 0.76521739, 0.78181818,
#            0.68965517, 0.74137931, 0.61538462, 0.73873874, 0.69565217,
#            0.76521739, 0.7079646 , 0.70175439, 0.64761905, 0.73846154,
#            0.75630252, 0.73684211, 0.73684211, 0.63157895, 0.72566372,
#            0.73214286, 0.76666667, 0.70149254, 0.7008547 , 0.75      ,
#            0.71186441, 0.7706422 , 0.71428571, 0.67826087, 0.63716814,
#            0.72727273, 0.68217054, 0.74766355, 0.73770492, 0.72881356,
#            0.69565217, 0.84684685, 0.67826087, 0.704     , 0.66019417,
#            0.73504274, 0.69491525, 0.6728972 , 0.75      , 0.67272727,
#            0.7107438 , 0.7826087 , 0.66666667, 0.7704918 , 0.69918699,
#            0.77586207, 0.68468468, 0.70588235, 0.72413793, 0.68965517,
#            0.71559633, 0.72131148, 0.81818182, 0.60869565, 0.75862069,
#            0.73504274, 0.68376068, 0.74782609, 0.81818182, 0.72881356,
#            0.64864865, 0.72727273, 0.6870229 , 0.71428571, 0.75      ,
#            0.73043478, 0.69090909, 0.6779661 , 0.69565217, 0.72727273,
#            0.69565217, 0.77477477, 0.75438596, 0.66101695, 0.7107438 ,
#            0.7107438 , 0.66666667, 0.7008547 , 0.79646018, 0.66071429,
#            0.66086957, 0.70689655, 0.79338843, 0.72413793, 0.78688525,
#            0.73873874, 0.7008547 , 0.65420561, 0.72727273, 0.77192982,
#            0.68518519, 0.765625  , 0.72413793, 0.6440678 , 0.74137931,
#            0.67716535, 0.75675676, 0.71794872, 0.67826087, 0.69158879,
#            0.69026549, 0.71428571, 0.76785714, 0.69918699, 0.75438596,
#            0.76666667, 0.72      , 0.75630252, 0.74766355, 0.75675676,
#            0.66071429, 0.65517241, 0.7008547 , 0.73394495, 0.69491525,
#            0.65420561, 0.69918699, 0.69421488, 0.72      , 0.73076923,
#            0.69642857, 0.703125  , 0.74074074, 0.65648855, 0.7394958 ,
#            0.70491803, 0.68965517, 0.74137931, 0.71666667, 0.75438596,
#            0.7079646 , 0.67826087, 0.68468468, 0.78688525, 0.71929825,
#            0.71186441, 0.66666667, 0.76422764, 0.74336283, 0.70909091,
#            0.76271186, 0.71304348, 0.74509804, 0.67175573, 0.69642857,
#            0.68376068, 0.79032258, 0.61403509, 0.7027027 , 0.67241379,
#            0.73873874, 0.77310924, 0.74015748, 0.76785714, 0.71428571,
#            0.69565217, 0.7704918 , 0.656     , 0.69811321, 0.72131148,
#            0.75675676, 0.73873874, 0.73015873, 0.71698113, 0.71186441,
#            0.73170732, 0.67889908, 0.70689655, 0.72268908, 0.71666667,
#            0.73684211, 0.69565217, 0.72881356, 0.67272727, 0.77586207])}}}}

# %%
rows = [['Sampling method','Accuracy', 'Precision', 'Recall','F-score']]

for datasetName, dataset in resultsByName.items():

    if datasetName != 'ProppLearner_from_allen_short':
        continue

    for samplingStratName, samplingStrat in dataset.items():

        row = ['$' + datasetName + ' ' + samplingStratName + '$']

        for expName, exp in samplingStrat.items():
        
            if expName == 'additional features':

                for measureName, res in exp.items():
                    row.append('$' +  str(res['avg'])  + '$')

        rows.append(row)

# %%
table = Texttable()
table.set_cols_align(["c"] * len(rows[0]))
table.set_deco(Texttable.HEADER | Texttable.VLINES)
table.add_rows(rows)

print('\nTexttable Table')
print(table.draw())

print('\nTexttable Latex:')
print(latextable.draw_latex(table, caption="F-Scores for the classification model, first 15 stories of ProppLearner SpanBERT"))
# Out:
# Texttable Table
#            Sampling method             | Accuracy | Precision | Recall | F-score
# =======================================+==========+===========+========+========
# $ProppLearner_from_allen_short normal$ |  $0.84$  |  $0.62$   | $0.84$ | $0.71$
#  $ProppLearner_from_allen_short over$  |  $0.85$  |  $0.65$   | $0.82$ | $0.72$
#     $ProppLearner_from_allen_short     |  $0.86$  |  $0.68$   | $0.77$ | $0.72$
#              over_under$               |          |           |        |
#
# Texttable Latex:
# \begin{table}
# 	\begin{center}
# 		\begin{tabular}{c|c|c|c|c}
# 			Sampling method & Accuracy & Precision & Recall & F-score \\
# 			\hline
# 			$ProppLearner_from_allen_short normal$ & $0.84$ & $0.62$ & $0.84$ & $0.71$ \\
# 			$ProppLearner_from_allen_short over$ & $0.85$ & $0.65$ & $0.82$ & $0.72$ \\
# 			$ProppLearner_from_allen_short over_under$ & $0.86$ & $0.68$ & $0.77$ & $0.72$ \\
# 		\end{tabular}
# 	\end{center}
# 	\caption{F-Scores for the classification model, first 15 stories of ProppLearner SpanBERT}
# \end{table}

# %% [markdown]
# ### Full Pipeline Results

# %% [markdown]
# #### Select Best Resuls

# %%
print('results -1:')
print(np.load('../results/full_pipeline/results.npy'))
print()

for i in range(5):
    print('results',str(i)+':')
    print(np.load('../results/full_pipeline/results' + str(i) + '.npy'))
# Out:
# results -1:
# [[[0.51820451 0.67615287 0.51820451 0.56943779]
#   [0.57911675 0.66920491 0.57911675 0.60328613]
#   [0.54826377 0.67615287 0.54826377 0.58798291]
#   [0.54596843 0.66920491 0.54596843 0.58363998]]
#
#  [[0.50500869 0.47331535 0.50500869 0.46565982]
#   [0.54261852 0.4614526  0.54261852 0.47724834]
#   [0.51124749 0.47331535 0.51124749 0.46928457]
#   [0.53490675 0.4614526  0.53490675 0.47303411]]
#
#  [[0.25094544 0.20032738 0.25094544 0.19247444]
#   [0.26525446 0.20032738 0.26525446 0.1941876 ]
#   [0.26099256 0.20032738 0.26099256 0.19307671]
#   [0.25520734 0.20032738 0.25520734 0.19358533]]]
#
# results 0:
# [[[0.5280132  0.67932327 0.5280132  0.57787541]
#   [0.58562531 0.67266632 0.58562531 0.60958732]
#   [0.55688612 0.67932327 0.55688612 0.59545249]
#   [0.55412102 0.67266632 0.55412102 0.59105327]]
#
#  [[0.5031799  0.47290169 0.5031799  0.4615705 ]
#   [0.5425092  0.46149646 0.5425092  0.47402802]
#   [0.50879764 0.47290169 0.50879764 0.4648382 ]
#   [0.53586727 0.46149646 0.53586727 0.4703454 ]]
#
#  [[0.23187897 0.2126267  0.23187897 0.18670642]
#   [0.25576339 0.2126267  0.25576339 0.1954297 ]
#   [0.23579315 0.2126267  0.23579315 0.18810827]
#   [0.25184921 0.2126267  0.25184921 0.19402785]]]
# results 1:
# [[[0.51917548 0.67848657 0.51917548 0.56880062]
#   [0.57722236 0.67096542 0.57722236 0.60082268]
#   [0.54704568 0.67848657 0.54704568 0.58609569]
#   [0.5459301  0.67096542 0.5459301  0.58241813]]
#
#  [[0.52230175 0.47903941 0.52230175 0.47270409]
#   [0.56020091 0.4679283  0.56020091 0.48490805]
#   [0.52727473 0.47903941 0.52727473 0.47552567]
#   [0.55417848 0.4679283  0.55417848 0.48161829]]
#
#  [[0.26282044 0.2056756  0.26282044 0.18712771]
#   [0.29290179 0.2056756  0.29290179 0.19537553]
#   [0.28150595 0.2056756  0.28150595 0.18952039]
#   [0.27421627 0.2056756  0.27421627 0.19298285]]]
# results 2:
# [[[0.50444834 0.67458    0.50444834 0.55991456]
#   [0.56878788 0.67109374 0.56878788 0.59820246]
#   [0.53614941 0.67458    0.53614941 0.58001686]
#   [0.53424331 0.67109374 0.53424331 0.5770396 ]]
#
#  [[0.49897608 0.47434906 0.49897608 0.46493168]
#   [0.53940972 0.46173468 0.53940972 0.47779996]
#   [0.50553986 0.47434906 0.50553986 0.46882526]
#   [0.53149612 0.46173468 0.53149612 0.47335173]]
#
#  [[0.26650694 0.21420918 0.26650694 0.19632809]
#   [0.30775347 0.21420918 0.30775347 0.20727578]
#   [0.28181002 0.21420918 0.28181002 0.19806198]
#   [0.2924504  0.21420918 0.2924504  0.20554189]]]
# results 3:
# [[[0.51726203 0.67562179 0.51726203 0.56905321]
#   [0.58185926 0.66855037 0.58185926 0.60436979]
#   [0.54859979 0.67562179 0.54859979 0.58817974]
#   [0.54659435 0.66855037 0.54659435 0.58410213]]
#
#  [[0.50114329 0.47490221 0.50114329 0.45819359]
#   [0.53854022 0.4637911  0.53854022 0.47136194]
#   [0.50654308 0.47490221 0.50654308 0.46166771]
#   [0.53224249 0.4637911  0.53224249 0.46748974]]
#
#  [[0.25131335 0.20043091 0.25131335 0.18787177]
#   [0.28726276 0.20043091 0.28726276 0.19806723]
#   [0.2583074  0.20043091 0.2583074  0.18841698]
#   [0.28019728 0.20043091 0.28019728 0.19744719]]]
# results 4:
# [[[0.52077992 0.67427771 0.52077992 0.56964833]
#   [0.57760904 0.6674973  0.57760904 0.60157436]
#   [0.5471281  0.67427771 0.5471281  0.58634317]
#   [0.54868844 0.6674973  0.54868844 0.58394943]]
#
#  [[0.50693173 0.47517192 0.50693173 0.46109848]
#   [0.5463474  0.46406081 0.5463474  0.47439655]
#   [0.51274907 0.47517192 0.51274907 0.46459866]
#   [0.53948436 0.46406081 0.53948436 0.47044585]]
#
#  [[0.26573958 0.22344515 0.26573958 0.20296323]
#   [0.29798214 0.22344515 0.29798214 0.2133924 ]
#   [0.2750119  0.22344515 0.2750119  0.20413873]
#   [0.28870982 0.22344515 0.28870982 0.21221689]]]

# %%
results0 = np.load('../results/full_pipeline/results' + str(0) + '.npy')
results1 = np.load('../results/full_pipeline/results' + str(1) + '.npy')
results4 = np.load('../results/full_pipeline/results' + str(4) + '.npy')

# %%
results = results0

best = [0,1,4]

rows = [['','Accuracy','Recall','Precision','F1']]
settingNames = ['ProppLearner', 'CEN', 'LitBank']

for i, (settingName, settingNum) in enumerate(zip(settingNames, range(len(settingNames)))):

    results = np.load('../results/full_pipeline/results' + str(best[i]) + '.npy')

    rowNames = ['No Post-processing', "Remove `and's and remove `None'","Remove `None'" , "Remove `and's"]
    
    for rowName, result in zip(rowNames, results[settingNum]):
        row = []
        row.append(rowName)
        for item in result:
            row.append('$' + str(np.round(item, 2)) + '$')

        rows.append(row)

# %%
table = Texttable()
table.set_cols_align(["c"] * len(rows[0]))
table.set_deco(Texttable.HEADER | Texttable.VLINES)
table.add_rows(rows)

print('\nTexttable Table')
print(table.draw())

print('\nTexttable Latex:')
print(latextable.draw_latex(table, caption="A comparison of F-scores the the classification model when features are constructed using AllenNLP vs using CoreNLP."))
# Out:
# Texttable Table
#                                 | Accuracy | Recall | Precision |   F1
# ================================+==========+========+===========+=======
#       No Post-processing        |  $0.53$  | $0.68$ |  $0.53$   | $0.58$
# Remove `and's and remove `None' |  $0.59$  | $0.67$ |  $0.59$   | $0.61$
#          Remove `None'          |  $0.56$  | $0.68$ |  $0.56$   | $0.6$
#          Remove `and's          |  $0.55$  | $0.67$ |  $0.55$   | $0.59$
#       No Post-processing        |  $0.52$  | $0.48$ |  $0.52$   | $0.47$
# Remove `and's and remove `None' |  $0.56$  | $0.47$ |  $0.56$   | $0.48$
#          Remove `None'          |  $0.53$  | $0.48$ |  $0.53$   | $0.48$
#          Remove `and's          |  $0.55$  | $0.47$ |  $0.55$   | $0.48$
#       No Post-processing        |  $0.27$  | $0.22$ |  $0.27$   | $0.2$
# Remove `and's and remove `None' |  $0.3$   | $0.22$ |   $0.3$   | $0.21$
#          Remove `None'          |  $0.28$  | $0.22$ |  $0.28$   | $0.2$
#          Remove `and's          |  $0.29$  | $0.22$ |  $0.29$   | $0.21$
#
# Texttable Latex:
# \begin{table}
# 	\begin{center}
# 		\begin{tabular}{c|c|c|c|c}
# 			 & Accuracy & Recall & Precision & F1 \\
# 			\hline
# 			No Post-processing & $0.53$ & $0.68$ & $0.53$ & $0.58$ \\
# 			Remove `and's and remove `None' & $0.59$ & $0.67$ & $0.59$ & $0.61$ \\
# 			Remove `None' & $0.56$ & $0.68$ & $0.56$ & $0.6$ \\
# 			Remove `and's & $0.55$ & $0.67$ & $0.55$ & $0.59$ \\
# 			No Post-processing & $0.52$ & $0.48$ & $0.52$ & $0.47$ \\
# 			Remove `and's and remove `None' & $0.56$ & $0.47$ & $0.56$ & $0.48$ \\
# 			Remove `None' & $0.53$ & $0.48$ & $0.53$ & $0.48$ \\
# 			Remove `and's & $0.55$ & $0.47$ & $0.55$ & $0.48$ \\
# 			No Post-processing & $0.27$ & $0.22$ & $0.27$ & $0.2$ \\
# 			Remove `and's and remove `None' & $0.3$ & $0.22$ & $0.3$ & $0.21$ \\
# 			Remove `None' & $0.28$ & $0.22$ & $0.28$ & $0.2$ \\
# 			Remove `and's & $0.29$ & $0.22$ & $0.29$ & $0.21$ \\
# 		\end{tabular}
# 	\end{center}
# 	\caption{A comparison of F-scores the the classification model when features are constructed using AllenNLP vs using CoreNLP.}
# \end{table}
