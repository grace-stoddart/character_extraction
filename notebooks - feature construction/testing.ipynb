# %%
import numpy as np

import sys
sys.path.append('../src')

from misc import open_dict, save_dict, get_file_names, get_raw_text, token_map, open_list, save_list
from character_features import SRL_feat, dep_feat, ner_feat, SRL_feat, len_feat, CN_feat, WN_feat, disp_feat, QU_feat, const_feat, get_arg0_positions, get_nsubj_positions, get_PER_positions, get_arg0s_const
from character_features_original import SRL_feat_original, dep_feat_original, ner_feat_original, openie_feat_original, CN_feat_original, WN_feat_original, openie_feat_coreNLP, ner_feat_coreNLP, dep_feat_coreNLP
from animacy import categorise_coref_chains

from settings import settings

# %% [markdown]
# ### comb features

# %%
def combine_features(featureNames, featuresDir, corpus = 'ProppLearner'):
    '''
    Combines specified features into a single array, which can be used by an SVM
    Parameters:
        featureNames - list containing feature names (i.e. feature FILE names) to be combined
        featuresDir - directory where feature files will be found
    Returns:
        featuresCombined - np array
    '''

    if corpus == 'ProppLearner':

        n = 46
        offset = 0

        # the first feature from story 1 will start the array
        npFileName = 'story' + str(1) + '.npy'
        featuresAll = np.atleast_2d(np.load(featuresDir + featureNames[0] + '/' + npFileName))

        # iterate through remaining features in story 1 and add to array
        for i in range(1, len(featureNames)):
            feature = np.atleast_2d(np.load(featuresDir + featureNames[i] + '/' + npFileName))
            featuresAll = np.concatenate((featuresAll, feature))

        # iterate through all remaining features in all remaining stories and add to array
        for storyNum in range(2 + offset,(n+1 + offset)):

            if storyNum == 34:
                continue

            npFileName = 'story' + str(storyNum) + '.npy'

            featuresThisStory = np.atleast_2d(np.load(featuresDir + featureNames[0] + '/' + npFileName))

            for i in range(1, len(featureNames)):
                feature = np.atleast_2d(np.load(featuresDir + featureNames[i] + '/' + npFileName))
                featuresThisStory = np.concatenate((featuresThisStory, feature))

            featuresAll = np.concatenate((featuresAll, featuresThisStory), axis = 1)
            

    else:
        print('need to add this corpus to function')

    return featuresAll.transpose()

# %%
experiments = {'ProppLearner_from_allen': 
                    {
                    'feature_names': ['SS', 'DP', 'CN', 'CD', 'CL', 'NE', 'WN', 'TR', 'animacy_labels_scraped', 'character_labels_scraped'],
                    'features_dir': "../intermediate/ProppLearner/from_allenNLP_corefs/",
                    'results_file_path': "../results/ProppLearner/from_allenNLP_corefs.txt",
                    },

                'ProppLearner_from_gold': 
                    {
                    'feature_names': ['SS', 'DP', 'CN', 'CD', 'CL', 'NE', 'WN', 'TR', 'animacy_labels_scraped', 'character_labels_scraped'],
                    'features_dir': "../intermediate/ProppLearner/from_allenNLP_corefs/",
                    'results_file_path': "../results/ProppLearner/from_allenNLP_corefs.txt",
                    },
                
                }

# %%
exp = experiments['ProppLearner_from_allen']
featureNames, featuresDir = exp['feature_names'], exp['features_dir']

# %%
n = 46
offset = 0

# the first feature from story 1 will start the array
npFileName = 'story' + str(1) + '.npy'
featuresAll = np.atleast_2d(np.load(featuresDir + featureNames[0] + '/' + npFileName))

# %%
featuresAll.shape
# Out:
# (1, 20)

# %%
# iterate through remaining features in story 1 and add to array
for i in range(1, len(featureNames)):
    feature = np.atleast_2d(np.load(featuresDir + featureNames[i] + '/' + npFileName))
    featuresAll = np.concatenate((featuresAll, feature))

# %%
featuresAll.shape
# Out:
# (10, 20)

# %%
npFileName = 'story' + str(4) + '.npy'

featuresThisStory = np.atleast_2d(np.load(featuresDir + featureNames[0] + '/' + npFileName))

for i in range(1, len(featureNames)):
    feature = np.atleast_2d(np.load(featuresDir + featureNames[i] + '/' + npFileName))
    featuresThisStory = np.concatenate((featuresThisStory, feature))

# print(featuresThisStory.shape)
# featuresAll = np.concatenate((featuresAll, featuresThisStory), axis = 0)

# %%
# iterate through all remaining features in all remaining stories and add to array
for storyNum in range(2 + offset,(n+1 + offset)):

    if storyNum == 34:
        continue

    npFileName = 'story' + str(storyNum) + '.npy'

    featuresThisStory = np.atleast_2d(np.load(featuresDir + featureNames[0] + '/' + npFileName))

    for i in range(1, len(featureNames)):
        feature = np.atleast_2d(np.load(featuresDir + featureNames[i] + '/' + npFileName))
        featuresThisStory = np.concatenate((featuresThisStory, feature))

    featuresAll = np.concatenate((featuresAll, featuresThisStory), axis = 1)

    # np.save(outputDir + "story" + str(storyNum), features)
# Out:
# (10, 20)
# (10, 32)
# (10, 34)
# (10, 29)
# (10, 33)
# (10, 34)
# (10, 36)
# (10, 36)
# (10, 23)
# (10, 40)
# (10, 32)
# (10, 47)
# (10, 36)
# (10, 55)
# (10, 36)
# (10, 29)
# (10, 25)
# (10, 44)
# (10, 22)
# (10, 34)
# (10, 28)
# (10, 37)
# (10, 35)
# (10, 40)
# (10, 43)
# (10, 59)
# (10, 64)
# (10, 32)
# (10, 24)
# (10, 50)
# (10, 56)
# (10, 65)
# (10, 112)
# (10, 68)
# (10, 94)
# (10, 95)
# (10, 83)
# (10, 102)
# (10, 67)
# (10, 64)
# (10, 86)
# (10, 48)
# (10, 33)
# (10, 49)

# %%
features.shape
# Out:
# (10, 49)

# %%
featuresAllStories = combine_features(featureNames, featuresDir)

# %%
featuresAllStories.shape
# Out:
# (2131, 10)

# %% [markdown]
# ### coref chains

# %%
corefsGoldDir = '../data/ProppLearner/corefs_gold_new_format/'
fileNames = get_file_names(corefsGoldDir, '.p')


goldCorefs = { }
for fileName in fileNames:

    corefs = open_dict(corefsGoldDir + fileName + '.p')
    simplified = []

    for chain in corefs['clusters']:
        refExps = ''
        for mention in chain['mentions']:
            refExps += mention['text']
            refExps += '    '
        simplified.append(refExps)


    goldCorefs[fileName] = simplified

# %%
goldCorefs['story1']
# Out:
# ['A dragon    he    he    the dragon    He    his    he    he    he    dragon    the dragon    the dragon    him    he    he    he    the wicked dragon    the dragon    the dragon    the dragon    him    dragon    the dragon    himself    your    you    The dragon    he    him    him    the dragon    me    I    I    the dragon    the dragon    he    the dragon    you    your    The dragon    him    him    ',
#  'Kiev    the city of Kiev    Kiev    his land    Kiev    Kiev    ',
#  'heavy tribute from the people - a lovely maiden from every house , whom he then devoured    ',
#  'the people    ',
#  'a lovely maiden from every house , whom he then devoured    ',
#  'every house    ',
#  "it    the fate of the tsar 's daughter to go to the dragon    ",
#  "the tsar 's daughter    her    her    her    she    a beauty    her    the princess    The princess    her    The princess    her    She    her    their daughter    her    The princess    the princess    she    her    her    the princess    ",
#  'tsar    father    tsar    her father    the tsar    his    the tsar    tsar    ',
#  "his lair    his house    the dragon 's lair    the dragon 's lair    your lair    ",
#  "a little dog that had followed her to the dragon 's lair    dog    the dog    ",
#  'her father and mother    them    the tsar and tsarina    their    the tsar and tsarina    they    ',
#  'mother    tsarina    tsarina    ',
#  'her letter    it    ',
#  "the dog 's neck    ",
#  'the answer    ',
#  'One day    ',
#  'who in this world was stronger than the dragon    ',
#  'this world    the world    ',
#  'a long time    ',
#  'one day    ',
#  'a tanner in the city of Kiev was stronger than he    this    ',
#  'a tanner in the city of Kiev    Nikita the Tanner    him    Nikita the Tanner    Nikita    his    he    him    he    his    he    him    he    him    him    Nikita    him    Nikita himself    he    He    himself    him    Nikita    Nikita    I    he    Nikita    he    Nikita    Nikita the Tanner    you    you    Nikita    He    Nikita    Nikita    Nikita    his    ',
#  'this letter    ',
#  'the tsar went in person to beg Nikita the Tanner to free his land from the wicked dragon and rescue the princess    the tsar in person had come to see him    ',
#  'hides    hides    ',
#  'twelve hides    the twelve hides    ',
#  'his hands    his hands    ',
#  'fear    ',
#  'five thousand little children    them    their    The little children    ',
#  'their tears    tears    theirs    ',
#  'tears    ',
#  'twelve thousand pounds of hemp    it    it    ',
#  'pitch    ',
#  'battle    ',
#  'the open field    the open field    ',
#  'your lair together with you    ',
#  'the door    ',
#  'trouble    ',
#  'a long time or a short time    ',
#  'no one in the world    ',
#  'you and I    us    us    we    We    us    ',
#  'all the earth , all the world    the whole earth    the earth    ',
#  'equal parts    ',
#  'one half    ',
#  'the other    ',
#  'a boundary line    a boundary    a furrow    That furrow    it    it    the furrow    it    it    the rampart    ',
#  'a plow that weighed twelve thousand pounds    it    ',
#  'twelve thousand pounds    ',
#  'the Caspian Sea    the sea    the sea    the sea    ',
#  'your water    ',
#  'the middle of the sea    ',
#  'this very day    ',
#  'fourteen feet    ',
#  'the fields    ',
#  'those who do not know what it is    ',
#  'his heroic deed    ',
#  'any reward    ']

# %% [markdown]
# ### features

# %%
tokensDir = '../data/ProppLearner/tokenized/'
corefDir = '../data/ProppLearner/corefs_allen/'
parsesDir = '../intermediate/ProppLearner/parses/'

srlParsesDir = parsesDir + 'SRL-bert/'
depParsesDir = parsesDir + 'deps-biaffine/'
nerParsesDir = parsesDir + 'NER-elmo/'
openParsesDir = parsesDir + 'openIE/'
constParsesDir = parsesDir + 'constituency/'

# %%
fileName = 'story1'
pFileName = 'story1.p'

document = open_dict(tokensDir + pFileName)
corefs = open_dict(corefDir + pFileName)
sentences = document['sents']
tokens = document['tokens']

srlParses = open_dict(srlParsesDir + pFileName)['parses']
depParses = open_dict(depParsesDir + pFileName)['parses']
nerParses = open_dict(nerParsesDir + pFileName)['parses']
openParses = open_dict(openParsesDir + pFileName)['parses']
constParses = open_dict(constParsesDir + pFileName)['parses']

# %% [markdown]
# #### SRL

# %%
nerFeat = ner_feat(nerParses, sentences, corefs)

# %%
pFileName = 'story7.p'
fileName = 'story7'

document = open_dict(tokensDir + pFileName)
corefs = open_dict(corefDir + pFileName)
sentences = document['sents']
tokens = document['tokens']

nerParses = open_dict(nerParsesDir + pFileName)
openieParses = open_dict(openParsesDir + pFileName)['parses']
depParses = open_dict(depParsesDir + pFileName)
srlParses = open_dict(srlParsesDir + pFileName)
annNER = open_dict('../intermediate/ProppLearner/parses/coreNLP_ner/' + pFileName)
corefs = open_dict(corefDir + pFileName)
ann = open_list('../intermediate/ProppLearner/parses/coreNLP/' + fileName + '.json')

# %%
from character_features_original import ner_feat_coreNLP, get_PER_list_core, get_people, ner_feat_original, get_dependency_subjs, get_chain_head, dep_feat_original, get_dependencies_list_core, dep_feat_coreNLP, get_triple_subjects, openie_feat_original, openie_feat_coreNLP, get_triple_subjects_core

# %%
get_triple_subjects(openieParses)
# Out:
# [[0, 0, 'This soldier'],
#  [0, 1, 'This soldier'],
#  [3, 1, 'His belly'],
#  [7, 0, 'the hardtack the soldier'],
#  [9, 0, 'the soldier'],
#  [9, 1, 'the soldier'],
#  [10, 0, 'the Unclean One with the appearance of an old man'],
#  [13, 0, 'The devil'],
#  [13, 1, 'the soldier'],
#  [14, 1, "'s do a trade"],
#  [14, 2, "'s"],
#  [19, 1, 'whoever'],
#  [19, 3, 'whoever looks at it'],
#  [19, 4, 'whoever looks at it'],
#  [21, 0, 'The soldier'],
#  [21, 1, 'The soldier'],
#  [23, 0, 'The Unclean One'],
#  [23, 1, 'The Unclean One'],
#  [23, 2, 'The Unclean One'],
#  [23, 4, 'things'],
#  [25, 5, 'this fiddle'],
#  [27, 0, 'the soldier'],
#  [29, 1, 'The soldier'],
#  [31, 0, 'the Unclean One'],
#  [35, 0, 'The soldier'],
#  [35, 1, 'The soldier'],
#  [35, 5, 'this unknown old man'],
#  [37, 0, 'The devil'],
#  [37, 1, 'a troika of fine horses'],
#  [38, 0, 'in'],
#  [40, 0, 'The soldier'],
#  [40, 3, 'by his eyes'],
#  [48, 0, 'The soldier'],
#  [48, 1, 'The soldier'],
#  [48, 2, 'they all'],
#  [48, 3, 'they all'],
#  [48, 6, 'leave'],
#  [48, 7, 'that he had been with the Unclean One for no'],
#  [49, 0, 'His leave'],
#  [50, 0, 'The soldier'],
#  [52, 0, 'leave him'],
#  [52, 1, 'His stupidity'],
#  [56, 2, 'the Unclean One'],
#  [57, 1, 'so sad'],
#  [58, 1, 'your service in the regiment'],
#  [58, 2, 'your service in the regiment'],
#  [62, 0, 'Merchants'],
#  [63, 0, 'The Unclean One'],
#  [63, 1, 'The Unclean One'],
#  [66, 0, 'The king there'],
#  [68, 0, 'our merchant'],
#  [68, 1, 'our merchant'],
#  [69, 0, 'Happiness'],
#  [71, 0, 'The other merchants'],
#  [72, 1, "'s"],
#  [76, 0, 'The merchants'],
#  [77, 0, 'The soldier'],
#  [80, 1, 'all his money'],
#  [84, 3, 'the daughter of your king'],
#  [85, 0, 'The sentry'],
#  [85, 1, 'the courtiers'],
#  [86, 0, 'The king'],
#  [87, 1, 'marry you to her'],
#  [88, 0, 'three decks of cards , three bottles of sweet wine'],
#  [89, 1, 'Good'],
#  [89, 1, 'all'],
#  [90, 0, 'The soldier'],
#  [90, 1, 'The soldier'],
#  [90, 2, 'The soldier'],
#  [92, 0, 'the Unclean One'],
#  [92, 1, 'the music'],
#  [92, 2, 'the Unclean One'],
#  [97, 0, 'some'],
#  [100, 0, 'The devil'],
#  [100, 1, 'his eyes'],
#  [103, 0, 'some nuts'],
#  [103, 3, 'the soldier'],
#  [107, 0, 'The king'],
#  [109, 0, 'thanks'],
#  [110, 0, 'The next night'],
#  [111, 0, 'the soldier'],
#  [111, 3, 'some pincers'],
#  [112, 1, 'Good'],
#  [112, 1, 'all'],
#  [113, 0, 'the Unclean One'],
#  [119, 0, 'The Unclean One'],
#  [119, 1, 'The Unclean One'],
#  [120, 2, 'the king'],
#  [120, 3, 'the king'],
#  [120, 5, 'some musicians'],
#  [121, 0, 'all their fingers'],
#  [121, 1, 'all their fingers'],
#  [122, 0, 'Oh , brother'],
#  [122, 0, 'the Unclean'],
#  [123, 2, 'the fiddle'],
#  [125, 0, 'your fingers'],
#  [126, 0, 'The devil'],
#  [126, 1, 'the soldier'],
#  [127, 2, 'the devil'],
#  [129, 1, 'the devil'],
#  [135, 1, 'grab you'],
#  [137, 0, 'the soldier'],
#  [137, 1, 'the soldier'],
#  [137, 2, 'the king'],
#  [138, 0, 'the new king and his wife'],
#  [140, 1, 'the princess'],
#  [141, 0, 'one to fall in love with'],
#  [141, 1, 'one'],
#  [142, 0, 'The king'],
#  [142, 1, 'The king'],
#  [143, 2, 'the Unclean One'],
#  [143, 3, 'the Unclean One'],
#  [147, 0, 'never get out of my claws'],
#  [151, 0, 'goodbye']]

# %%
positions = []
offset = 0
for i, parse in enumerate(openieParses):

    for j, verb in enumerate(parse['verbs']):

        print(verb['description'])

        tags = []
        for tag in verb['tags']:
            tags.append(tag.split('-')[-1])
            tags = list(set(tags))

        for j in range(len(tags)-1, -1, -1):
            if tags[j] == 'O':
                del tags[j]
        
        if len(tags) < 3:
            continue

        for j in range(0,5):
            if 'ARG' + str(j) in tags:
                subjTag = 'ARG' + str(j)
                break
        print(subjTag)

        for k, tag in enumerate(verb['tags']):
            if tag == 'B-'+subjTag:

                count = 1

                while k + count < len(verb['tags']):
                    if verb['tags'][k + count] != 'I-' + subjTag:
                        break
                    count += 1

                positions.append([k + offset, k + offset + count -1])
        
                for pos in range(k + offset, k + offset + count):
                    print(document['tokens'][pos] + ' ', end='')

                break
        print()

    offset += len(sentences[i]['tokens'])
# Out:
# [ARG0: This soldier] [V: got] [ARG1: permission to go on leave] .
# ARG0
# This soldier
# [ARG0: This soldier] got permission to [V: go] [ARG2: on leave] .
# ARG0
# This soldier
# [ARG1: He] [V: got] [ARG2: ready] and set off along the way .
# ARG1
# He
# [ARG1: He] got ready and [V: set] off [ARGM-LOC: along the way] .
# ARG1
# He
# [ARG0: He] [V: walked] and walked , but nowhere did he see any water and he wanted to wet his hardtack and eat a little along the way and road .
# [ARG0: He] walked and [V: walked] , but nowhere did he see any water and he wanted to wet his hardtack and eat a little along the way and road .
# He walked and walked , but nowhere [V: did] he see any water and he wanted to wet his hardtack and eat a little along the way and road .
# He walked and walked , but nowhere did [ARG0: he] [V: see] [ARG1: any water] and he wanted to wet his hardtack and eat a little along the way and road .
# ARG0
# he
# He walked and walked , but nowhere did he see any water and [ARG0: he] [V: wanted] [ARG1: to wet his hardtack and eat a little along the way and road] .
# ARG0
# he
# He walked and walked , but nowhere did he see any water and [ARG0: he] wanted to [V: wet] [ARG1: his hardtack] and eat a little along the way and road .
# ARG0
# he
# He walked and walked , but nowhere did he see any water and [ARG0: he] wanted to wet his hardtack and [V: eat] [ARGM-EXT: a little] [ARGM-LOC: along the way and road] .
# ARG0
# he
# His belly [V: had] long since been empty .
# [ARG1: His belly] had long since [V: been] [ARG2: empty] .
# ARG1
# His belly
# There [V: was] [ARG1: nothing to be done] and so he dragged himself on a bit further .
# There was nothing to [V: be] done and so he dragged himself on a bit further .
# There was [ARG1: nothing] to be [V: done] and so he dragged himself on a bit further .
# There was nothing to be done and [ARGM-DIS: so] [ARG0: he] [V: dragged] [ARG1: himself] [ARGM-DIR: on] [ARGM-EXT: a bit further] .
# ARG0
# he
# [ARGM-TMP: Then] [ARG0: he] [V: looked] and saw a creek running .
# ARG0
# he
# [ARGM-TMP: Then] [ARG0: he] looked and [V: saw] [ARG1: a creek running] .
# ARG0
# he
# Then he looked and saw [ARG0: a creek] [V: running] .
# [ARG0: He] [V: went] [ARGM-DIR: up] [ARG4: to this creek] and got three biscuits out of his pack and put them in the water .
# ARG0
# He
# [ARG0: He] went up to this creek and [V: got] [ARG1: three biscuits] [ARG2: out of his pack] and put them in the water .
# ARG0
# He
# [ARG0: He] went up to this creek and got three biscuits out of his pack and [V: put] [ARG1: them] [ARG2: in the water] .
# ARG0
# He
# [ARGM-DIS: Besides] [ARG0: the hardtack the soldier] [V: had] [ARG1: this fiddle] .
# ARG0
# the hardtack the soldier
# [ARGM-TMP: In his free time] [ARG0: he] [V: played] [ARG1: various songs] [ARGM-PRP: to chase away his boredom] .
# ARG0
# he
# In his free time [ARG0: he] played various songs to [V: chase] [ARGM-DIR: away] [ARG1: his boredom] .
# ARG0
# he
# [ARGM-DIS: So] [ARG1: the soldier] [V: sat] down [ARGM-LOC: next to the stream] and began playing .
# ARG1
# the soldier
# [ARGM-DIS: So] [ARG0: the soldier] sat down next to the stream and [V: began] [ARG1: playing] .
# ARG0
# the soldier
# So [ARG0: the soldier] sat down next to the stream and began [V: playing] .
# [ARGM-ADV: Suddenly out of nowhere] [ARG1: the Unclean One with the appearance of an old man] [V: came] [ARGM-DIR: up] [ARG4: to him] [ARGM-MNR: with a book in his hands] .
# ARG1
# the Unclean One with the appearance of an old man
# [ARG0: The devil] [V: wrinkled] up [ARG1: his face] [ARGM-TMP: when the soldier addressed him as " My good man] ! "
# ARG0
# The devil
# The devil wrinkled up his face [ARGM-TMP: when] [ARG0: the soldier] [V: addressed] [ARG1: him] [ARG2: as " My good man] ! "
# ARG0
# the soldier
# " [V: Listen] , [ARGM-DIS: my friend] : let 's do a trade .
# " [ARGM-DIS: Listen , my friend] : [V: let] [ARG1: 's do a trade] .
# ARG1
# 's do a trade
# " Listen , my friend : let [ARG0: 's] [V: do] [ARG1: a trade] .
# ARG0
# 's
# I 'll give you my book and you give me your fiddle . "
# [ARG0: I] [ARGM-MOD: 'll] [V: give] [ARG2: you] [ARG1: my book] and you give me your fiddle . "
# ARG0
# I
# I 'll give you my book and [ARG0: you] [V: give] [ARG2: me] [ARG1: your fiddle] . "
# ARG0
# you
# " Oh , old man , why [V: do] I need your book ?
# " Oh , old man , [ARGM-CAU: why] do [ARG0: I] [V: need] [ARG1: your book] ?
# ARG0
# I
# I [V: 've] served his majesty for ten years but I 've never been able to read or write .
# [ARG0: I] 've [V: served] [ARG2: his majesty] [ARGM-TMP: for ten years] but I 've never been able to read or write .
# ARG0
# I
# I 've served his majesty for ten years but I [V: 've] never been able to read or write .
# I 've served his majesty for ten years but [ARG1: I] 've [ARGM-NEG: never] [V: been] [ARG2: able to read or write] .
# ARG1
# I
# I 've served his majesty for ten years but [ARG0: I] 've never been able to [V: read] or write .
# I 've served his majesty for ten years but [ARG0: I] 've never been able to read or [V: write] .
# I [V: did] n't know how before and now it 's too late to learn . "
# [ARG0: I] did [ARGM-NEG: n't] [V: know] [ARG1: how before and now it 's too late to learn] . "
# ARG0
# I
# I did n't know how [ARGM-TMP: before and now] [ARG1: it] [V: 's] [ARG2: too late to learn] . "
# ARG1
# it
# I did n't know how before and now it 's too late to [V: learn] . "
# " [ARGM-ADV: Never mind] , [ARGM-DIS: soldier] , [ARG1: this] [V: is] [ARG2: the sort of book that whoever looks at it will be able to read] . "
# ARG1
# this
# " Never mind , soldier , this is the sort of book that [ARG0: whoever] [V: looks] [ARG1: at it] will be able to read . "
# ARG0
# whoever
# " Never mind , soldier , this is the sort of book that whoever looks at it [V: will] be able to read . "
# " Never mind , soldier , this is the sort of book that [ARG1: whoever looks at it] [ARGM-MOD: will] [V: be] [ARG2: able to read] . "
# ARG1
# whoever looks at it
# " Never mind , soldier , this is the sort of book [R-ARG1: that] [ARG0: whoever looks at it] will be able to [V: read] . "
# ARG0
# whoever looks at it
# " [ARGM-DIS: Alright] , [V: give] [ARG1: it] [ARG2: to me] and I 'll try . "
# ARG1
# it
# " Alright , give it to me and I [V: 'll] [ARG1: try] . "
# " Alright , give it to me and [ARG0: I] [ARGM-MOD: 'll] [V: try] . "
# ARG0
# I
# [ARG0: The soldier] [V: opened] up [ARG1: the book] and started reading , [ARGM-ADV: just as if he had done so from his early years] .
# ARG0
# The soldier
# [ARG0: The soldier] opened up the book and [V: started] [ARG1: reading] , [ARGM-ADV: just as if he had done so from his early years] .
# ARG0
# The soldier
# [ARG0: The soldier] opened up the book and started [V: reading] , just as if he had done so from his early years .
# The soldier opened up the book and started reading , just as if he [V: had] done so from his early years .
# The soldier opened up the book and started reading , just as if [ARG0: he] had [V: done] [ARG1: so] [ARGM-TMP: from his early years] .
# ARG0
# he
# [ARG1: He] [V: was] [ARG2: delighted] and immediately handed over his fiddle .
# ARG1
# He
# [ARG0: He] was delighted and [ARGM-TMP: immediately] [V: handed] over [ARG1: his fiddle] .
# ARG0
# He
# [ARG0: The Unclean One] [V: took] [ARG1: it] and began working at it with the bow , but no way did things go right !
# ARG0
# The Unclean One
# [ARG0: The Unclean One] took it and [V: began] [ARG1: working at it with the bow] , but no way did things go right !
# ARG0
# The Unclean One
# [ARG0: The Unclean One] took it and began [V: working] [ARGM-LOC: at it] [ARGM-MNR: with the bow] , but no way did things go right !
# ARG0
# The Unclean One
# The Unclean One took it and began working at it with the bow , but no way [V: did] things go right !
# The Unclean One took it and began working at it with the bow , but no way did [ARG1: things] [V: go] [ARG2: right] !
# ARG1
# things
# He [V: could] [ARG1: n't make it play anything at all] .
# [ARG0: He] [ARGM-MOD: could] [ARGM-NEG: n't] [V: make] [ARG1: it play anything at all] .
# ARG0
# He
# He could n't make [ARG0: it] [V: play] [ARG1: anything at all] .
# ARG0
# it
# " [V: Listen] , [ARGM-DIS: brother] , " he said to the soldier , " Let me stay as your guest for a couple of days and you teach me how to play this fiddle .
# " Listen , brother , " [ARG0: he] [V: said] [ARG2: to the soldier] , " [ARG1: Let me stay as your guest for a couple of days and you teach me how to play this fiddle] .
# ARG0
# he
# " Listen , brother , " he said to the soldier , " [V: Let] [ARG1: me stay as your guest for a couple of days] and you teach me how to play this fiddle .
# " Listen , brother , " he said to the soldier , " Let [ARG1: me] [V: stay] [ARG3: as your guest] [ARGM-TMP: for a couple of days] and you teach me how to play this fiddle .
# ARG1
# me
# " Listen , brother , " he said to the soldier , " Let me stay as your guest for a couple of days and [ARG0: you] [V: teach] [ARG2: me] [ARG1: how to play this fiddle] .
# ARG0
# you
# " Listen , brother , " he said to the soldier , " Let me stay as your guest for a couple of days and you teach me [ARGM-MNR: how] to [V: play] [ARG1: this fiddle] .
# ARG1
# this fiddle
# I [V: 'll] be very grateful . "
# [ARG1: I] [ARGM-MOD: 'll] [V: be] [ARG2: very grateful] . "
# ARG1
# I
# " [ARG1: No , old man] , " [ARG0: the soldier] [V: answered] , " [ARG2: I have to go on home and in three days I 'll be far , far away] . "
# ARG0
# the soldier
# " No , old man , " the soldier answered , " I [V: have] to go on home and in three days I 'll be far , far away . "
# " No , old man , " the soldier answered , " [ARG0: I] have to [V: go] [ARG4: on home] and in three days I 'll be far , far away . "
# ARG0
# I
# " No , old man , " the soldier answered , " I have to go on home and in three days I [V: 'll] be far , far away . "
# " No , old man , " the soldier answered , " I have to go on home and [ARGM-TMP: in three days] [ARG1: I] [ARGM-MOD: 'll] [V: be] [ARG2: far , far away] . "
# ARG1
# I
# " Please , soldier , if you [V: 'll] [ARG1: stay] and teach me to play this fiddle , I 'll get you home in a single day - by a postal troika I 'll drive you right there . "
# " Please , soldier , if [ARG1: you] [ARGM-MOD: 'll] [V: stay] and teach me to play this fiddle , I 'll get you home in a single day - by a postal troika I 'll drive you right there . "
# ARG1
# you
# " Please , soldier , if [ARG0: you] [ARGM-MOD: 'll] stay and [V: teach] [ARG2: me] [ARG1: to play this fiddle] , I 'll get you home in a single day - by a postal troika I 'll drive you right there . "
# ARG0
# you
# " Please , soldier , if you 'll stay and teach [ARG0: me] to [V: play] [ARG1: this fiddle] , I 'll get you home in a single day - by a postal troika I 'll drive you right there . "
# ARG0
# me
# " [ARGM-DIS: Please] , soldier , [ARGM-ADV: if you 'll stay and teach me to play this] fiddle , [ARG0: I] [V: 'll] [ARG1: get you home in a single day] - by a postal troika I 'll drive you right there . "
# ARG0
# I
# " [ARGM-DIS: Please , soldier] , [ARGM-ADV: if you 'll stay and teach me to play this fiddle] , [ARG0: I] [ARGM-MOD: 'll] [V: get] [ARG1: you] [ARG2: home in a single day] - [ARGM-MNR: by a postal troika] I 'll drive you right there . "
# ARG0
# I
# " Please , soldier , if you 'll stay and teach me to play this fiddle , I 'll get you home in a single day - by a postal troika [ARG0: I] [V: 'll] [ARG1: drive you] right there . "
# ARG0
# I
# " Please , soldier , if you 'll stay and teach me to play this fiddle , I 'll get you home in a single day - by a postal troika [ARG0: I] [ARGM-MOD: 'll] [V: drive] [ARG1: you] [ARGM-LOC: right there] . "
# ARG0
# I
# [ARG1: The soldier] [V: sat] and thought : should he stay or not ?
# [ARG0: The soldier] sat and [V: thought] : [ARG1: should he stay or not ?]
# ARG0
# The soldier
# The soldier sat and thought : [V: should] he stay or not ?
# The soldier sat and thought : [ARGM-MOD: should] [ARG1: he] [V: stay] or not ?
# ARG1
# he
# [ARG0: He] [V: took] [ARG1: the hardtack] [ARGM-DIR: out of the stream] [ARGM-TMP: as he wanted to eat something] .
# ARG0
# He
# He took the hardtack out of the stream as [ARG0: he] [V: wanted] [ARG1: to eat something] .
# ARG0
# he
# He took the hardtack out of the stream as [ARG0: he] wanted to [V: eat] [ARG1: something] .
# ARG0
# he
# " [ARG1: Oh , brother soldier] , " [V: said] [ARG0: the Unclean One] .
# ARG0
# the Unclean One
# " [ARG1: That] [V: 's] [ARG2: really awful stuff you 've got there] .
# ARG1
# That
# " That 's really awful stuff you [V: 've] got there .
# " That 's really awful stuff [ARG0: you] 've [V: got] [ARG2: there] .
# ARG0
# you
# [V: Eat] [ARG1: with me] ! "
# [ARG0: He] [V: opened] [ARG1: his sack] and got some white bread , some roast beef and vodka , and all sorts of other things : " Eat it , I do n't want to . "
# ARG0
# He
# [ARG0: He] opened his sack and [V: got] [ARG1: some white bread , some roast beef and vodka , and all sorts of other things] : " Eat it , I do n't want to . "
# ARG0
# He
# He opened his sack and got some white bread , some roast beef and vodka , and all [V: sorts] [ARG1: of other things] : " Eat it , I do n't want to . "
# He opened his sack and got some white bread , some roast beef and vodka , and all sorts of other things : " [V: Eat] [ARG1: it] , I do n't want to . "
# He opened his sack and got some white bread , some roast beef and vodka , and all sorts of other things : " Eat it , I [V: do] n't want to . "
# He opened his sack and got some white bread , some roast beef and vodka , and all sorts of other things : " Eat it , [ARG0: I] do [ARGM-NEG: n't] [V: want] [ARG1: to] . "
# ARG0
# I
# [ARG0: The soldier] [V: ate] and drank [ARG1: his fill] and then he agreed to stay on and teach this unknown old man how to play the fiddle .
# ARG0
# The soldier
# [ARG0: The soldier] ate and [V: drank] [ARG1: his fill] and then he agreed to stay on and teach this unknown old man how to play the fiddle .
# ARG0
# The soldier
# The soldier ate and drank his fill and [ARGM-TMP: then] [ARG0: he] [V: agreed] [ARG1: to stay on and teach this unknown old man how to play the fiddle] .
# ARG0
# he
# The soldier ate and drank his fill and then [ARG1: he] agreed to [V: stay] [ARG3: on] and teach this unknown old man how to play the fiddle .
# ARG1
# he
# The soldier ate and drank his fill and then [ARG0: he] agreed to stay on and [V: teach] [ARG2: this unknown old man] [ARG1: how to play the fiddle] .
# ARG0
# he
# The soldier ate and drank his fill and then he agreed to stay on and teach [ARG0: this unknown old man] [ARGM-MNR: how] to [V: play] [ARG1: the fiddle] .
# ARG0
# this unknown old man
# [ARG1: He] [V: stayed] [ARG3: with him] [ARGM-TMP: for three days] and then he asked to go home .
# ARG1
# He
# He stayed with him for three days and [ARGM-TMP: then] [ARG0: he] [V: asked] [ARG1: to go home] .
# ARG0
# he
# He stayed with him for three days and then [ARG0: he] asked to [V: go] [ARG4: home] .
# ARG0
# he
# [ARG0: The devil] [V: led] [ARG1: him] [ARG4: outside and there] [ARGM-TMP: before the porch stood a troika of fine horses] .
# ARG0
# The devil
# The devil led him outside and there before [ARG2: the porch] [V: stood] [ARG1: a troika of fine horses] .
# ARG1
# a troika of fine horses
# " [V: Get] [ARG2: in] , [ARGM-DIS: soldier] !
# ARG2
# in
# I 'll get you there in an instant ! "
# [ARG0: I] [ARGM-MOD: 'll] [V: get] [ARG1: you] [ARGM-LOC: there] [ARGM-TMP: in an instant] ! "
# ARG0
# I
# [ARG0: The soldier] [V: got] [ARG2: in the cart] and they started the horses and so he went home - and how many versts flashed by his eyes !
# ARG0
# The soldier
# The soldier got in the cart and [ARG0: they] [V: started] [ARG1: the horses] and so he went home - and how many versts flashed by his eyes !
# ARG0
# they
# The soldier got in the cart and they started the horses and [ARGM-ADV: so] [ARG0: he] [V: went] [ARG4: home] - and how many versts flashed by his eyes !
# ARG0
# he
# The soldier got in the cart and they started the horses and so he went home - and [ARG1: how many versts] [V: flashed] [ARG0: by his eyes] !
# ARG0
# by his eyes
# [ARG1: He] [V: got] [ARG2: there] [ARGM-LOC: in nothing flat] .
# ARG1
# He
# " But [V: will] [ARG1: you recognize the village] ? "
# " [ARGM-DIS: But] [ARGM-MOD: will] [ARG0: you] [V: recognize] [ARG1: the village] ? "
# ARG0
# you
# [V: asked] [ARG2: the Unclean One] .
# " How [V: could] I not know it ! "
# " [ARGM-MNR: How] [ARGM-MOD: could] [ARG0: I] [ARGM-NEG: not] [V: know] [ARG1: it] ! "
# ARG0
# I
# [ARG0: the soldier] [V: replied] .
# " I [V: was] born in this village and I grew up here . "
# " [ARG1: I] was [V: born] [ARGM-LOC: in this village] and I grew up here . "
# ARG1
# I
# " I was born in this village and [ARG1: I] [V: grew] up [ARGM-LOC: here] . "
# ARG1
# I
# [ARG1: The soldier] [V: got] [ARG2: down] [ARG2: from the cart] , went in to his relatives , and they all exchanged greetings and asked about each other , for how long and when he had been given leave , It seemed to him that he had been with the Unclean One for no more than three days but in fact it had been three years .
# ARG1
# The soldier
# [ARG0: The soldier] got down from the cart , [V: went] [ARGM-DIR: in] [ARG4: to his relatives] , and they all exchanged greetings and asked about each other , for how long and when he had been given leave , It seemed to him that he had been with the Unclean One for no more than three days but in fact it had been three years .
# ARG0
# The soldier
# The soldier got down from the cart , went in to his relatives , and [ARG0: they all] [V: exchanged] [ARG1: greetings] and asked about each other , for how long and when he had been given leave , It seemed to him that he had been with the Unclean One for no more than three days but in fact it had been three years .
# ARG0
# they all
# The soldier got down from the cart , went in to his relatives , and [ARG0: they all] exchanged greetings and [V: asked] [ARG1: about each other] , for how long and when he had been given leave , It seemed to him [ARG1: that he had been with the Unclean One for no more than three] days but in fact it had been three years .
# ARG0
# they all
# The soldier got down from the cart , went in to his relatives , and they all exchanged greetings and asked about each other , for how long and when he [V: had] been given leave , It seemed to him that he had been with the Unclean One for no more than three days but in fact it had been three years .
# The soldier got down from the cart , went in to his relatives , and they all exchanged greetings and asked about each other , for how long and when he had [V: been] given leave , It seemed to him that he had been with the Unclean One for no more than three days but in fact it had been three years .
# The soldier got down from the cart , went in to his relatives , and they all exchanged greetings and asked about each other , for [ARGM-TMP: how long and] [ARGM-TMP: when] [ARG2: he] had been [V: given] [ARG1: leave] , It seemed to him that he had been with the Unclean One for no more than three days but in fact it had been three years .
# ARG1
# leave
# The soldier got down from the cart , went in to his relatives , and they all exchanged greetings and asked about each other , for [ARGM-TMP: how long and when he had been given leave] , It [V: seemed] [ARG2: to him] [ARG1: that he had been with the Unclean One for no more than three days but in fact it had been three years] .
# ARG1
# that he had been with the Unclean One for no more than three days but in fact it had been three years
# The soldier got down from the cart , went in to his relatives , and they all exchanged greetings and asked about each other , for how long and when he had been given leave , It seemed to him that he [V: had] been with the Unclean One for no more than three days but in fact it had been three years .
# The soldier got down from the cart , went in to his relatives , and they all exchanged greetings and asked about each other , for how long and when he had been given leave , It seemed to him that [ARG1: he] had [V: been] [ARG2: with the Unclean One] [ARGM-TMP: for no more than three days] but in fact it had been three years .
# ARG1
# he
# The soldier got down from the cart , went in to his relatives , and they all exchanged greetings and asked about each other , for how long and when he had been given leave , It seemed to him that he had been with the Unclean One for no more than three days but in fact it [V: had] been three years .
# The soldier got down from the cart , went in to his relatives , and they all exchanged greetings and asked about each other , for how long and when he had been given leave , It seemed to him that he had been with the Unclean One for no more than three days but [ARGM-ADV: in fact] [ARG1: it] had [V: been] [ARG2: three years] .
# ARG1
# it
# [ARG0: His leave] [V: had] [ARGM-TMP: long since finished] and he was considered a runaway in his regiment .
# ARG0
# His leave
# [ARG1: His leave] had long since [V: finished] and he was considered a runaway in his regiment .
# His leave had long since finished and he [V: was] considered a runaway in his regiment .
# His leave had long since finished and he was [V: considered] [ARG1: a runaway in his regiment] .
# [ARG1: The soldier] [V: became] [ARG2: timid] .
# ARG1
# The soldier
# He [V: did] n't know what to do .
# [ARG0: He] did [ARGM-NEG: n't] [V: know] [ARG1: what to do] .
# ARG0
# He
# [ARG0: He] did n't know [ARG1: what] to [V: do] .
# ARG0
# He
# His stupidity [ARGM-ADV: simply] [V: would] n't [ARG1: leave him] .
# ARG1
# leave him
# [ARG0: His stupidity] [ARGM-ADV: simply] [ARGM-MOD: would] [ARGM-NEG: n't] [V: leave] [ARG1: him] .
# ARG0
# His stupidity
# [ARG0: He] [V: went] [ARG4: outside] and thought , " Now where am I to go ?
# ARG0
# He
# [ARG0: He] went outside and [V: thought] , " [ARG1: Now where am I to go] ?
# ARG0
# He
# He went outside and thought , " Now [ARG2: where] [V: am] [ARG1: I] [C-ARG2: to go] ?
# ARG1
# I
# He went outside and thought , " Now [ARG4: where] am [ARG0: I] to [V: go] ?
# ARG0
# I
# If [ARG0: I] [V: go] [ARG4: back to the regiment] , they 'll run me through the gauntlet .
# ARG0
# I
# [ARGM-ADV: If I go back to the regiment] , [ARG0: they] [V: 'll] [ARG1: run me through the gauntlet] .
# ARG0
# they
# [ARGM-ADV: If I go back to the regiment] , [ARG0: they] [ARGM-MOD: 'll] [V: run] [ARG1: me] [ARGM-MNR: through the gauntlet] .
# ARG0
# they
# Oh , Unclean One , you [V: 've] played a nasty trick on me . "
# [ARGM-DIS: Oh] , [ARGM-DIS: Unclean One] , [ARG0: you] 've [V: played] [ARG1: a nasty trick on me] . "
# ARG0
# you
# [ARG0: He] [V: had] [ARG1: no sooner spoken these words than the Unclean One was there] .
# ARG0
# He
# [ARG0: He] had [ARGM-TMP: no sooner] [V: spoken] [ARG1: these words than the Unclean One was there] .
# ARG0
# He
# He had no sooner spoken these words than [ARG1: the Unclean One] [V: was] [ARG2: there] .
# ARG1
# the Unclean One
# " [V: Do] n't be so sad , soldier !
# " Do [ARGM-NEG: n't] [V: be] [ARG2: so sad] , [ARGM-DIS: soldier] !
# ARG2
# so sad
# [V: Stay] [ARG3: with me] ; your service in the regiment was n't much to brag about .
# Stay with me ; [ARG1: your service in the regiment] [V: was] [ARGM-NEG: n't] [ARG2: much to brag about] .
# ARG1
# your service in the regiment
# Stay with me ; [ARG0: your service in the regiment] was n't much to [V: brag] [ARG1: about] .
# ARG0
# your service in the regiment
# [ARG0: They] [V: gave] [ARG2: you] [ARG1: dry biscuits to eat] and they beat you with sticks .
# ARG0
# They
# They gave you [ARG1: dry biscuits] to [V: eat] and they beat you with sticks .
# They gave you dry biscuits to eat and [ARG0: they] [V: beat] [ARG1: you] [ARGM-MNR: with sticks] .
# ARG0
# they
# I 'll make you happy - Do you want me to make you a merchant ? "
# [ARG0: I] [ARGM-MOD: 'll] [V: make] [ARG1: you happy - Do you want me to make you] a merchant ? "
# ARG0
# I
# I 'll make you happy - [V: Do] you want me to make you a merchant ? "
# I 'll make you happy - Do [ARG0: you] [V: want] [ARG1: me to make you a merchant] ? "
# ARG0
# you
# I 'll make you happy - Do you want [ARG0: me] to [V: make] [ARGM-GOL: you] [ARG1: a merchant] ? "
# ARG0
# me
# " Alright , that [V: would] be fine .
# " [ARGM-DIS: Alright] , [ARG1: that] [ARGM-MOD: would] [V: be] [ARG2: fine] .
# ARG1
# that
# [ARG0: Merchants] [V: live] [ARGM-MNR: well] and I 'd like to try happiness . "
# ARG0
# Merchants
# Merchants live well and [ARG0: I] [V: 'd] [ARG1: like] [ARG1: to try happiness] . "
# ARG0
# I
# Merchants live well and [ARG0: I] [ARGM-MOD: 'd] [V: like] [ARG1: to try happiness] . "
# ARG0
# I
# Merchants live well and [ARG0: I] 'd like to [V: try] [ARG1: happiness] . "
# ARG0
# I
# [ARG0: The Unclean One] [V: made] [ARG1: him a merchant] and gave him a large shop in the capital city with all sorts of valuable goods and he said .
# ARG0
# The Unclean One
# [ARG0: The Unclean One] made him a merchant and [V: gave] [ARG2: him] [ARG1: a large shop in the capital city with all sorts of valuable goods] and he said .
# ARG0
# The Unclean One
# The Unclean One made him a merchant and gave him a large shop in the capital city with all sorts of valuable goods and [ARG0: he] [V: said] .
# I [V: 'll] be going beyond the thrice - nine land into the thrice - ten land .
# I 'll [V: be] going beyond the thrice - nine land into the thrice - ten land .
# [ARG0: I] [ARGM-MOD: 'll] be [V: going] [ARG4: beyond the thrice - nine land] [ARG4: into the thrice - ten land] .
# ARG0
# I
# [ARG0: The king there] [V: has] [ARG1: a splendid daughter , Princess Maria] .
# ARG0
# The king there
# I [V: 'm] going to torment her . "
# I 'm [V: going] to torment her . "
# [ARG0: I] 'm going to [V: torment] [ARG2: her] . "
# ARG0
# I
# [ARGM-DIS: So] [ARG0: our merchant] [V: lived] and worried about nothing .
# ARG0
# our merchant
# [ARGM-DIS: So] [ARG0: our merchant] lived and [V: worried] [ARG1: about nothing] .
# ARG0
# our merchant
# [ARG1: Happiness] [ARGM-ADV: just] [V: tumbled] [ARG4: onto his household] .
# ARG1
# Happiness
# [ARGM-DIS: And] [ARGM-LOC: in his trading] [ARG0: he] [V: had] [ARG1: just one task : to become even more prosperous] .
# ARG0
# he
# And in his trading he had just one task : to [V: become] [ARG2: even more prosperous] .
# [ARG1: The other merchants] [V: became] [ARG2: envious] , [ARGM-ADV: however] .
# ARG1
# The other merchants
# " [V: Let] [ARG1: 's ask him what sort of person he is , where he came from] , and does he know how to trade here ?
# " Let [ARG0: 's] [V: ask] [ARG2: him] [ARG1: what sort of person he is , where he came from] , and does he know how to trade here ?
# ARG0
# 's
# " Let 's ask him [ARG2: what sort of person] [ARG1: he] [V: is] , where he came from , and does he know how to trade here ?
# ARG1
# he
# " Let 's ask him what sort of person he is , where [ARG1: he] [V: came] [ARG3: from] , and does he know how to trade here ?
# ARG1
# he
# " Let 's ask him what sort of person he is , where he came from , and [V: does] he know how to trade here ?
# " Let 's ask him what sort of person he is , where he came from , and does [ARG0: he] [V: know] [ARG1: how to trade here] ?
# ARG0
# he
# " Let 's ask him what sort of person he is , where he came from , and does [ARG0: he] know [ARGM-MNR: how] to [V: trade] [ARGM-LOC: here] ?
# ARG0
# he
# Why , he [V: 's] taken all our trade away - let him have nothing for a while ! "
# [ARGM-CAU: Why] , [ARG0: he] 's [V: taken] [ARG1: all our trade] [ARGM-DIR: away] - let him have nothing for a while ! "
# ARG0
# he
# [ARGM-CAU: Why] , [ARG0: he] 's taken all our trade away - [V: let] [ARG1: him have nothing for a while] ! "
# ARG0
# he
# Why , he 's taken all our trade away - let [ARG0: him] [V: have] [ARG1: nothing for a while] ! "
# ARG0
# him
# [ARGM-DIS: So] [ARG0: they] [V: went] [ARG4: to him] and questioned him , and he replied to them : " My brothers , now I 've got so much business that I 've no time to discuss this with you .
# ARG0
# they
# [ARGM-DIS: So] [ARG0: they] went to him and [V: questioned] [ARG2: him] , and he replied to them : " My brothers , now I 've got so much business that I 've no time to discuss this with you .
# ARG0
# they
# So they went to him and questioned him , and [ARG0: he] [V: replied] [ARG1: to them] : " [ARG2: My brothers ,] now I 've got so much business that I 've no time to discuss this with you .
# ARG0
# he
# So they went to him and questioned him , and he replied to them : " My brothers , now I [V: 've] got so much business that I 've no time to discuss this with you .
# So they went to him and questioned him , and he replied to them : " [ARGM-DIS: My brothers] , [ARGM-TMP: now] [ARG0: I] 've [V: got] [ARG1: so much business that I 've no time to discuss this with you] .
# ARG0
# I
# So they went to him and questioned him , and he replied to them : " My brothers , now I 've got so much business that [ARG0: I] [V: 've] [ARG1: no time to discuss this with you] .
# ARG0
# I
# So they went to him and questioned him , and he replied to them : " My brothers , now I 've got so much business that I 've [ARGM-TMP: no time] to [V: discuss] [ARG1: this] [ARG2: with you] .
# ARG1
# this
# [V: Come] [ARGM-TMP: tomorrow] and you 'll find out everything . "
# Come tomorrow and you [V: 'll] [ARG1: find] out everything . "
# Come tomorrow and [ARG0: you] [ARGM-MOD: 'll] [V: find] out [ARG1: everything] . "
# ARG0
# you
# [ARG0: The merchants] [V: went] [ARG1: their separate ways to their own homes] .
# ARG0
# The merchants
# [ARG0: The soldier] [V: thought] : [ARG1: what should he do] ?
# ARG0
# The soldier
# The soldier thought : what [V: should] [ARG1: he do] ?
# The soldier thought : [ARG1: what] [ARGM-MOD: should] [ARG0: he] [V: do] ?
# ARG0
# he
# How [V: should] he answer them ?
# [ARGM-MNR: How] [ARGM-MOD: should] [ARG0: he] [V: answer] [ARG1: them] ?
# ARG0
# he
# [ARG0: He] [V: thought] and thought and then he decided to leave his shop and go out of the town that very night .
# [ARG0: He] thought and [V: thought] and then he decided to leave his shop and go out of the town that very night .
# He thought and thought and [ARGM-TMP: then] [ARG0: he] [V: decided] [ARG1: to leave his shop and go out of the town that very night] .
# ARG0
# he
# He thought and thought and then [ARG0: he] decided to [V: leave] [ARG1: his shop] and go out of the town that very night .
# ARG0
# he
# He thought and thought and then [ARG1: he] decided to leave his shop and [V: go] [ARGM-DIR: out of the town] that [ARGM-TMP: very night] .
# ARG1
# he
# [ARGM-DIS: So] [ARG0: he] [V: took] [ARG1: all his money that was to hand] and set out for the thrice - ten kingdom .
# ARG0
# he
# So he took [ARG1: all his money] [R-ARG1: that] [V: was] [ARG2: to hand and set out for the thrice - ten kingdom] .
# ARG1
# all his money
# So he took all his money [ARG1: that] was to [V: hand] and set out [ARG2: for the thrice - ten kingdom] .
# ARG1
# that
# [ARGM-DIS: So] [ARG0: he] took all his money that was to hand and [V: set] out [ARG2: for the thrice - ten kingdom] .
# ARG0
# he
# [ARG0: He] [V: walked] and walked [ARGM-TMP: until he came to a barrier] .
# ARG0
# He
# [ARG0: He] walked and [V: walked] [ARGM-TMP: until he came to a barrier] .
# ARG0
# He
# He walked and walked until [ARG1: he] [V: came] [ARG4: to a barrier] .
# ARG1
# he
# " [ARG2: Who] [V: are] [ARG1: you] ? "
# ARG1
# you
# [V: asked] [ARG2: the sentry] .
# " [ARG1: I] [V: am] [ARG2: a doctor] and I 'm coming to your tsardom because the daughter of your king is ill and I want to cure her , " he answered .
# ARG1
# I
# " I am a doctor and I [V: 'm] coming to your tsardom because the daughter of your king is ill and I want to cure her , " he answered .
# " I am a doctor and [ARG1: I] 'm [V: coming] [ARG4: to your tsardom] [ARGM-CAU: because the daughter of your king is ill and I want to cure her] , " he answered .
# ARG1
# I
# " I am a doctor and I 'm coming to your tsardom because [ARG1: the daughter of your king] [V: is] [ARG2: ill] and I want to cure her , " he answered .
# ARG1
# the daughter of your king
# " I am a doctor and I 'm coming to your tsardom because the daughter of your king is ill and [ARG0: I] [V: want] [ARG1: to cure her] , " he answered .
# ARG0
# I
# " I am a doctor and I 'm coming to your tsardom because the daughter of your king is ill and [ARG0: I] want to [V: cure] [ARG2: her] , " he answered .
# ARG0
# I
# " [ARG1: I am a doctor and I 'm coming to your tsardom because the daughter of your king is ill and I want to cure her] , " [ARG0: he] [V: answered] .
# ARG0
# he
# [ARG0: The sentry] [V: reported] [ARG1: this] [ARG2: to the courtiers] and the courtiers reported this to the king himself .
# ARG0
# The sentry
# The sentry reported this to the courtiers and [ARG0: the courtiers] [V: reported] [ARG1: this] [ARG2: to the king himself] .
# ARG0
# the courtiers
# [ARG0: The king] [V: called] in [ARG1: the soldier] .
# ARG0
# The king
# " If [ARG0: you] [V: cure] [ARG1: my daughter] , I 'll marry you to her . "
# ARG0
# you
# " [ARGM-ADV: If you cure my daughter] , I [V: 'll] [ARG1: marry you to her] . "
# ARG1
# marry you to her
# " [ARGM-ADV: If you cure my daughter] , [ARG1: I] [ARGM-MOD: 'll] [V: marry] [ARG2: you] [ARGM-GOL: to her] . "
# ARG1
# I
# " [ARGM-ADV: Your majesty] , [ARGM-ADV: just] [V: give] [ARG2: me] [ARG1: three decks of cards , three bottles of sweet wine , three bottles of strong spirits , three pounds of nuts , three pounds of bullets , and three bundles of strong wax candles] . "
# ARG1
# three decks of cards , three bottles of sweet wine , three bottles of strong spirits , three pounds of nuts , three pounds of bullets , and three bundles of strong wax candles
# " Good , all [V: will] be ready . "
# " [ARG1: Good] , [ARG1: all] [ARGM-MOD: will] [V: be] [ARG2: ready] . "
# ARG1
# Good
# [ARG1: The soldier] [V: waited] [ARGM-TMP: until evening] , bought himself a fiddle , and set off to the princess 's .
# ARG1
# The soldier
# [ARG0: The soldier] waited until evening , [V: bought] [ARGM-REC: himself] [ARG1: a fiddle] , and set off to the princess 's .
# ARG0
# The soldier
# [ARG0: The soldier] waited until evening , bought himself a fiddle , and [V: set] off [ARG2: to the princess 's] .
# ARG0
# The soldier
# [ARGM-LOC: In her rooms] [ARG0: he] [V: lit] [ARG1: the candles] and began drinking and carousing , and playing on his fiddle .
# ARG0
# he
# [ARGM-LOC: In her rooms] [ARG0: he] lit the candles and [V: began] [ARG1: drinking and carousing] , and playing on his fiddle .
# ARG0
# he
# In her rooms [ARG0: he] lit the candles and began [V: drinking] and carousing , and playing on his fiddle .
# In her rooms [ARG0: he] lit the candles and began drinking and carousing , and [V: playing] [ARGM-MNR: on his fiddle] .
# ARG0
# he
# [ARGM-TMP: At midnight] [ARG1: the Unclean One] [V: came] , heard the music , and rushed to the soldier .
# ARG1
# the Unclean One
# [ARGM-TMP: At midnight the Unclean One came] , [V: heard] [ARG1: the music] , and rushed to the soldier .
# ARG1
# the music
# [ARGM-TMP: At midnight] [ARG1: the Unclean One] came , heard the music , and [V: rushed] [ARG2: to the soldier] .
# ARG1
# the Unclean One
# " What [V: are] you drinking ? "
# " [ARG1: What] are [ARG0: you] [V: drinking] ? "
# ARG0
# you
# " I [V: 'm] sipping a little kvass . "
# " [ARG0: I] 'm [V: sipping] [ARG1: a little kvass] . "
# ARG0
# I
# " [V: Give] [ARG2: me] [ARG1: some] . "
# ARG1
# some
# [ARGM-DIS: But] [ARG0: he] [V: brought] [ARG2: him] [ARG1: a full glass of the strong spirits] .
# ARG0
# he
# [ARG0: The devil] [V: drank] [ARG1: it] [ARGM-LOC: all] and his eyes popped right out on his forehead .
# ARG0
# The devil
# The devil drank it all and [ARG1: his eyes] [V: popped] [ARGM-LOC: right out] [ARGM-LOC: on his forehead] .
# ARG1
# his eyes
# " [ARGM-DIS: Oh] , [ARG1: that] [V: 's] [ARG2: strong stuff you 've got] .
# ARG1
# that
# " Oh , that 's strong stuff you [V: 've] got .
# " Oh , that 's [ARG1: strong stuff] [ARG0: you] 've [V: got] .
# ARG0
# you
# [V: Let] [ARG1: me have a bite to eat] . "
# Let [ARG0: me] [V: have] [ARG1: a bite to eat] . "
# ARG0
# me
# Let me have [ARG1: a bite] to [V: eat] . "
# " [ARG2: Here] [V: are] [ARG1: some nuts] , take them and eat , " the soldier said , but he gave him some bullets .
# ARG1
# some nuts
# " Here are some nuts , [V: take] [ARG1: them] and eat , " the soldier said , but he gave him some bullets .
# " Here are some nuts , take them and [V: eat] , " the soldier said , but he gave him some bullets .
# [ARG1: " Here are some nuts , take them and eat] , " [ARG0: the soldier] [V: said] , but he gave him some bullets .
# ARG0
# the soldier
# " Here are some nuts , take them and eat , " the soldier said , but [ARG0: he] [V: gave] [ARG2: him] [ARG1: some bullets] .
# ARG0
# he
# [ARG0: The devil] [V: chewed] and chewed , but he just broke his teeth .
# [ARG0: The devil] chewed and [V: chewed] , but he just broke his teeth .
# The devil chewed and chewed , but [ARG0: he] [ARGM-ADV: just] [V: broke] [ARG1: his teeth] .
# ARG0
# he
# [ARGM-TMP: Then] [ARG0: they] [V: started] [ARG1: playing cards] .
# ARG0
# they
# Then [ARG0: they] started [V: playing] [ARG1: cards] .
# ARG0
# they
# Meanwhile , [ARG1: time] [V: passed] , the cocks crowed , and the Unclean One disappeared .
# Meanwhile , time passed , [ARG0: the cocks] [V: crowed] , and the Unclean One disappeared .
# Meanwhile , time passed , the cocks crowed , and [ARG1: the Unclean One] [V: disappeared] .
# [ARG0: The king] [V: asked] [ARG2: the princess] .
# ARG0
# The king
# " How [V: did] you sleep last night ? "
# " [ARGM-MNR: How] did [ARG0: you] [V: sleep] [ARGM-TMP: last night] ? "
# ARG0
# you
# " Peacefully , [ARG1: thanks] [V: be] [ARG2: to God] ! "
# ARG1
# thanks
# [ARG1: The next night] [V: passed] [ARGM-MNR: the same way] .
# ARG1
# The next night
# [ARGM-DIS: But] [ARGM-TMP: on the third night] [ARG0: the soldier] [V: asked] [ARG2: the king] : " [ARG1: Your majesty , order them to make some pincers weighing fifty pounds and three brass rods , three iron ones , and three lead ones] . "
# ARG0
# the soldier
# But on the third night the soldier asked the king : " Your majesty , [V: order] [ARG1: them] [ARG2: to make some pincers weighing fifty pounds and three brass rods , three iron ones , and three lead ones] . "
# ARG1
# them
# But on the third night the soldier asked the king : " Your majesty , order [ARG0: them] to [V: make] [ARG2: some pincers weighing] [ARG1: fifty pounds and three brass rods , three iron ones , and three lead ones] . "
# ARG0
# them
# But on the third night the soldier asked the king : " Your majesty , order them to make [ARG0: some pincers] [V: weighing] [ARG1: fifty pounds] and three brass rods , three iron ones , and three lead ones . "
# ARG0
# some pincers
# " Good , all [V: will] be ready . "
# " [ARG1: Good] , [ARG1: all] [ARGM-MOD: will] [V: be] [ARG2: ready] . "
# ARG1
# Good
# [ARGM-TMP: At deepest midnight] [ARG1: the Unclean One] [V: appeared] .
# ARG1
# the Unclean One
# I [V: 've] come to carouse with you again . "
# [ARG1: I] 've [V: come] [ARG4: to carouse] [ARGM-COM: with you] [ARGM-TMP: again] . "
# ARG1
# I've
# [ARG0: I] 've come to [V: carouse] [ARG1: with you] [ARGM-TMP: again] . "
# ARG0
# I've
# [ARG1: Who] [V: is] [ARGM-NEG: n't] [ARG2: happy with a cheerful companion] ! "
# ARG1
# Who
# [ARG0: They] [V: started] [ARG1: drinking and carousing] .
# ARG0
# They
# [ARG0: They] started [V: drinking] and carousing .
# [ARG0: The Unclean One] [V: saw] [ARG1: the pincers] and asked , " What is that ? "
# ARG0
# The Unclean One
# [ARG0: The Unclean One] saw the pincers and [V: asked] , " [ARG1: What is that] ? "
# ARG0
# The Unclean One
# The Unclean One saw the pincers and asked , " [ARG2: What] [V: is] [ARG1: that] ? "
# ARG1
# that
# " Well , [ARG0: you] [V: see] , the king has taken me into his service and ordered me to teach some musicians to play the fiddle .
# " Well , you see , the king [V: has] taken me into his service and ordered me to teach some musicians to play the fiddle .
# " [ARGM-DIS: Well] , you see , [ARG0: the king] has [V: taken] [ARG1: me] [ARG2: into his service] and ordered me to teach some musicians to play the fiddle .
# ARG0
# the king
# " [ARGM-DIS: Well] , you see , [ARG0: the king] has taken me into his service and [V: ordered] [ARG1: me] [ARG2: to teach some musicians to play the fiddle] .
# ARG0
# the king
# " Well , you see , the king has taken me into his service and ordered [ARG0: me] to [V: teach] [ARG2: some musicians] [ARG1: to play the fiddle] .
# ARG0
# me
# " Well , you see , the king has taken me into his service and ordered me to teach [ARG0: some musicians] to [V: play] [ARG1: the fiddle] .
# ARG0
# some musicians
# [ARGM-DIS: But] [ARG1: all their fingers] [V: are] [ARG2: crooked , no better than yours] , and so I 've got to straighten them out in these pincers . "
# ARG1
# all their fingers
# But [ARG1: all their fingers] are [V: crooked] , [ARGM-MNR: no better than yours] , and so I 've got to straighten them out in these pincers . "
# ARG1
# all their fingers
# But all their fingers are crooked , no better than yours , and so I [V: 've] got to straighten them out in these pincers . "
# But all their fingers are crooked , no better than yours , and so [ARG0: I] 've [V: got] [ARG1: to straighten them out in these pincers] . "
# ARG0
# I
# But all their fingers are crooked , no better than yours , and so [ARG0: I] 've got to [V: straighten] [ARG1: them] out [ARGM-LOC: in these pincers] . "
# ARG0
# I
# " [ARG0: Oh , brother] , " [V: asked] [ARG0: the Unclean] One , " [ARG1: Could n't you straighten out my fingers] ?
# ARG0
# Oh , brother
# " Oh , brother , " asked the Unclean One , " [V: Could] [ARG1: n't you straighten out my fingers] ?
# " Oh , brother , " asked the Unclean One , " [ARGM-MOD: Could] [ARGM-NEG: n't] [ARG0: you] [V: straighten] out [ARG1: my fingers] ?
# ARG0
# you
# I still [V: do] n't know how to play the fiddle . "
# [ARG0: I] [ARGM-TMP: still] do [ARGM-NEG: n't] [V: know] [ARG1: how to play the fiddle] . "
# ARG0
# I
# I still do n't know [ARGM-MNR: how] to [V: play] [ARG1: the fiddle] . "
# ARG1
# the fiddle
# [V: Put] [ARG1: your fingers] [ARGM-LOC: just here] . "
# ARG1
# your fingers
# [ARG0: The devil] [V: put] [ARG1: both hands] [ARG2: in the pincers] and the soldier squeezed them .
# ARG0
# The devil
# The devil put both hands in the pincers and [ARG0: the soldier] [V: squeezed] [ARG1: them] .
# ARG0
# the soldier
# [ARGM-TMP: Then] [ARG0: he] [V: picked] up [ARG1: the rods] and let the devil have it !
# ARG0
# he
# [ARGM-TMP: Then] [ARG0: he] picked up the rods and [V: let] [ARG1: the devil have it] !
# ARG0
# he
# Then he picked up the rods and let [ARG0: the devil] [V: have] [ARG1: it] !
# ARG0
# the devil
# [ARG0: He] [V: beat] [ARG1: him] and repeated , " This is for your merchant 's work ! "
# ARG0
# He
# [ARG0: He] beat him and [V: repeated] , " [ARG1: This is for your merchant 's work] ! "
# ARG0
# He
# He beat him and repeated , " [ARG1: This] [V: is] [ARG2: for your merchant 's work] ! "
# ARG1
# This
# [ARG0: The devil] [V: pleaded] , the devil begged , " Let me go , please !
# The devil pleaded , [ARG0: the devil] [V: begged] , " [ARG2: Let me go , please] !
# ARG0
# the devil
# The devil pleaded , the devil begged , " [V: Let] [ARG1: me go] , please !
# The devil pleaded , the devil begged , " Let [ARG0: me] [V: go] , please !
# I [V: 'll] never come within thirty versts of the palace again ! "
# [ARG1: I] [ARGM-MOD: 'll] [ARGM-NEG: never] [V: come] [ARG2: within thirty versts of the palace] [ARGM-ADV: again] ! "
# ARG1
# I
# [ARGM-DIS: But] [ARG0: he] [V: kept] on [ARG1: flogging him] .
# ARG0
# he
# But [ARG0: he] kept on [V: flogging] [ARG1: him] .
# ARG0
# he
# [ARG0: The devil] [V: hopped] and hopped .
# [ARG0: The devil] hopped and [V: hopped] .
# [ARG0: He] [V: twisted] and twisted .
# [ARG0: He] twisted and [V: twisted] .
# [ARGM-ADV: With all his might] [ARG1: he] [V: broke] [ARGM-PRD: loose] and said to the soldier , " Even if you marry the princess , you wo n't get out of my hands .
# ARG1
# he
# [ARGM-ADV: With all his] [ARGM-MOD: might] [ARG0: he] broke loose and [V: said] [ARG2: to the soldier] , " [ARG1: Even if you marry the princess , you wo n't get out of my hands] .
# ARG0
# he
# With all his might he broke loose and said to the soldier , " Even if [ARG1: you] [V: marry] [ARG2: the princess] , you wo n't get out of my hands .
# ARG1
# you
# With all his might he broke loose and said to the soldier , " [ARGM-ADV: Even if you marry the princess] , [ARG0: you] [V: wo] [ARG1: n't get out of my hands] .
# ARG0
# you
# With all his might he broke loose and said to the soldier , " [ARGM-ADV: Even if you marry the princess] , [ARG1: you] [ARGM-MOD: wo] [ARGM-NEG: n't] [V: get] [ARG2: out of my hands] .
# ARG1
# you
# Once [ARG1: you] [V: go] [ARG2: beyond the thirty versts] , I 'll grab you ! "
# ARG1
# you
# [ARGM-TMP: Once you go beyond the thirty versts] , I [V: 'll] [ARG1: grab you] ! "
# ARG1
# grab you
# [ARGM-TMP: Once you go beyond the thirty versts] , [ARG0: I] [ARGM-MOD: 'll] [V: grab] [ARG1: you] ! "
# ARG0
# I
# When he [V: had] said this , he disappeared .
# [ARGM-TMP: When] [ARG0: he] had [V: said] [ARG1: this] , he disappeared .
# ARG0
# he
# [ARGM-TMP: When he had said this] , [ARG1: he] [V: disappeared] .
# ARG1
# he
# [ARGM-DIS: So] [ARG1: the soldier] [V: married] [ARG2: the princess] and lived with her in love and harmony , and then after several years the king died and he began ruling the entire tsardom .
# ARG1
# the soldier
# [ARGM-DIS: So] [ARG0: the soldier] married the princess and [V: lived] [ARGM-COM: with her] [ARGM-MNR: in love and harmony] , and then after several years the king died and he began ruling the entire tsardom .
# ARG0
# the soldier
# So the soldier married the princess and lived with her in love and harmony , and then after [ARGM-TMP: several years] [ARG1: the king] [V: died] and he began ruling the entire tsardom .
# ARG1
# the king
# So the soldier married the princess and lived with her in love and harmony , and then after several years the king died and [ARG0: he] [V: began] [ARG1: ruling the entire tsardom] .
# ARG0
# he
# So the soldier married the princess and lived with her in love and harmony , and then after several years the king died and [ARG0: he] began [V: ruling] [ARG1: the entire tsardom] .
# ARG0
# he
# [ARGM-TMP: Once] [ARG0: the new king and his wife] [V: went] [ARG4: into the garden] [ARGM-PRP: to walk] .
# ARG0
# the new king and his wife
# Once [ARG0: the new king and his wife] went into the garden to [V: walk] .
# " [ARG1: Oh , what a lovely garden] , " [ARG0: he] [V: said] .
# ARG0
# he
# " [ARG1: This] [V: is] n't [ARG2: much of a garden] , " said the princess .
# ARG1
# This
# " [ARG1: This is n't much of a garden] , " [V: said] [ARG0: the princess] .
# ARG0
# the princess
# " [ARGM-LOC: Just outside the town ,] [ARGM-LOC: about thirty versts from here] , there [V: is] [ARG1: one to fall in love with] . "
# ARG1
# one to fall in love with
# " Just outside the town , about thirty versts from here , there is [ARG1: one] to [V: fall] [ARG2: in love] with . "
# ARG1
# one
# [ARG1: The king] [V: got] [ARG2: ready] and drove there with the queen .
# ARG1
# The king
# [ARG0: The king] got ready and [V: drove] [ARG1: there] [ARG2: with the queen] .
# ARG0
# The king
# When he [V: had] stepped down from the carriage , the Unclean One came up and said .
# [ARGM-TMP: When] [ARG0: he] had [V: stepped] down [ARGM-DIR: from the carriage] , the Unclean One came up and said .
# ARG0
# he
# [ARGM-TMP: When he had stepped down from the carriage] , [ARG1: the Unclean One] [V: came] up and said .
# ARG1
# the Unclean One
# [ARGM-TMP: When he had stepped down from the carriage] , [ARG0: the Unclean One] came up and [V: said] .
# ARG0
# the Unclean One
# " Why [V: have] you come ?
# " [ARGM-CAU: Why] have [ARG1: you] [V: come] ?
# ARG1
# you
# [V: Have] you perhaps forgotten what you were told ?
# Have [ARG0: you] [ARGM-ADV: perhaps] [V: forgotten] [ARG1: what you were told] ?
# ARG0
# you
# Have you perhaps forgotten what you [V: were] told ?
# Have you perhaps forgotten [ARG1: what] [ARG0: you] were [V: told] ?
# ARG0
# you
# [ARGM-DIS: Well] , [ARGM-DIS: brother] , [ARG1: you] [V: are] [ARG2: at fault yourself] .
# ARG1
# you
# [ARGM-TMP: Now] you [V: 'll] [ARG1: never get out of my claws] . "
# ARG1
# never get out of my claws
# [ARGM-TMP: Now] [ARG1: you] [ARGM-MOD: 'll] [ARGM-NEG: never] [V: get] [ARG2: out of my claws] . "
# ARG1
# you
# What [V: was] [ARG1: he] [ARG2: to do] ?
# ARG1
# he
# [ARG1: What] was [ARG0: he] to [V: do] ?
# ARG0
# he
# " [ARG1: That] [V: is] [ARGM-ADV: clearly] [ARG2: my fate] .
# ARG1
# That
# [V: Let] [ARG1: me say farewell to my young wife] . "
# Let [ARG0: me] [V: say] [ARG1: farewell] [ARG2: to my young wife] . "
# ARG0
# me
# " [V: Say] [ARG1: goodbye] [ARGM-TMP: then] , but hurry ! "
# ARG1
# goodbye
# " Say goodbye then , but [V: hurry] ! "

# %%
def get_triple_subject_positions(openieParses, sentences):

    positions = []
    offset = 0
    for i, parse in enumerate(openieParses):

        for j, verb in enumerate(parse['verbs']):


            tags = []
            for tag in verb['tags']:
                tags.append(tag.split('-')[-1])
                tags = list(set(tags))

            for j in range(len(tags)-1, -1, -1):
                if tags[j] == 'O':
                    del tags[j]
            
            if len(tags) < 3:
                continue

            for j in range(0,5):
                if 'ARG' + str(j) in tags:
                    subjTag = 'ARG' + str(j)
                    break

            for k, tag in enumerate(verb['tags']):
                if tag == 'B-'+subjTag:

                    count = 1

                    while k + count < len(verb['tags']):
                        if verb['tags'][k + count] != 'I-' + subjTag:
                            break
                        count += 1

                    positions.append([k + offset, k + offset + count -1])
                    break

        offset += len(sentences[i]['tokens'])

    return positions

# %%
get_triple_subject_positions(openieParses, sentences)
# Out:
# [[0, 1],
#  [0, 1],
#  [9, 9],
#  [9, 9],
#  [27, 27],
#  [32, 32],
#  [32, 32],
#  [32, 32],
#  [48, 49],
#  [64, 64],
#  [73, 73],
#  [73, 73],
#  [81, 81],
#  [81, 81],
#  [81, 81],
#  [103, 106],
#  [115, 115],
#  [115, 115],
#  [126, 127],
#  [126, 127],
#  [142, 151],
#  [181, 182],
#  [188, 189],
#  [206, 209],
#  [206, 206],
#  [211, 211],
#  [218, 218],
#  [233, 233],
#  [238, 238],
#  [247, 247],
#  [257, 257],
#  [265, 265],
#  [279, 279],
#  [286, 286],
#  [286, 289],
#  [286, 289],
#  [301, 301],
#  [305, 305],
#  [310, 311],
#  [310, 311],
#  [323, 323],
#  [332, 332],
#  [332, 332],
#  [342, 344],
#  [342, 344],
#  [342, 344],
#  [360, 360],
#  [364, 364],
#  [368, 368],
#  [380, 380],
#  [388, 388],
#  [399, 399],
#  [405, 406],
#  [408, 408],
#  [422, 423],
#  [427, 427],
#  [437, 437],
#  [452, 452],
#  [452, 452],
#  [457, 457],
#  [463, 463],
#  [463, 463],
#  [477, 477],
#  [477, 477],
#  [485, 486],
#  [492, 492],
#  [497, 497],
#  [506, 506],
#  [506, 506],
#  [520, 522],
#  [525, 525],
#  [530, 530],
#  [540, 540],
#  [540, 540],
#  [567, 567],
#  [574, 575],
#  [574, 575],
#  [583, 583],
#  [583, 583],
#  [583, 583],
#  [590, 593],
#  [600, 600],
#  [609, 609],
#  [609, 609],
#  [615, 616],
#  [626, 630],
#  [634, 634],
#  [638, 638],
#  [648, 649],
#  [655, 655],
#  [661, 661],
#  [670, 672],
#  [674, 674],
#  [684, 684],
#  [698, 698],
#  [709, 709],
#  [716, 716],
#  [728, 729],
#  [728, 729],
#  [743, 744],
#  [743, 744],
#  [762, 762],
#  [768, 789],
#  [769, 769],
#  [785, 785],
#  [791, 792],
#  [807, 808],
#  [812, 812],
#  [812, 812],
#  [825, 826],
#  [820, 821],
#  [828, 828],
#  [828, 828],
#  [838, 838],
#  [838, 838],
#  [843, 843],
#  [850, 850],
#  [850, 850],
#  [863, 863],
#  [873, 873],
#  [873, 873],
#  [881, 883],
#  [891, 892],
#  [900, 904],
#  [900, 904],
#  [912, 912],
#  [920, 920],
#  [926, 926],
#  [933, 933],
#  [935, 935],
#  [946, 946],
#  [951, 951],
#  [955, 955],
#  [955, 955],
#  [955, 955],
#  [963, 965],
#  [963, 965],
#  [997, 997],
#  [1010, 1012],
#  [1021, 1021],
#  [1030, 1031],
#  [1030, 1031],
#  [1038, 1038],
#  [1049, 1049],
#  [1061, 1063],
#  [1071, 1071],
#  [1078, 1078],
#  [1082, 1082],
#  [1088, 1088],
#  [1088, 1088],
#  [1097, 1097],
#  [1097, 1097],
#  [1106, 1106],
#  [1115, 1115],
#  [1115, 1115],
#  [1124, 1124],
#  [1134, 1134],
#  [1141, 1141],
#  [1147, 1147],
#  [1154, 1154],
#  [1161, 1162],
#  [1172, 1173],
#  [1178, 1178],
#  [1183, 1183],
#  [1193, 1193],
#  [1193, 1193],
#  [1193, 1193],
#  [1210, 1210],
#  [1212, 1214],
#  [1215, 1215],
#  [1210, 1210],
#  [1227, 1227],
#  [1227, 1227],
#  [1232, 1232],
#  [1241, 1241],
#  [1249, 1249],
#  [1254, 1254],
#  [1261, 1265],
#  [1269, 1269],
#  [1269, 1269],
#  [1276, 1276],
#  [1279, 1280],
#  [1287, 1288],
#  [1296, 1297],
#  [1305, 1305],
#  [1312, 1315],
#  [1310, 1310],
#  [1325, 1358],
#  [1362, 1362],
#  [1370, 1371],
#  [1370, 1371],
#  [1370, 1371],
#  [1392, 1392],
#  [1392, 1392],
#  [1392, 1392],
#  [1410, 1412],
#  [1416, 1417],
#  [1410, 1412],
#  [1438, 1438],
#  [1443, 1443],
#  [1454, 1454],
#  [1462, 1462],
#  [1473, 1474],
#  [1479, 1480],
#  [1491, 1491],
#  [1495, 1495],
#  [1500, 1500],
#  [1511, 1512],
#  [1520, 1521],
#  [1525, 1525],
#  [1538, 1538],
#  [1545, 1545],
#  [1545, 1545],
#  [1565, 1566],
#  [1574, 1574],
#  [1583, 1583],
#  [1589, 1591],
#  [1602, 1603],
#  [1613, 1613],
#  [1613, 1613],
#  [1616, 1617],
#  [1637, 1637],
#  [1648, 1650],
#  [1658, 1658],
#  [1658, 1658],
#  [1670, 1670],
#  [1680, 1680],
#  [1686, 1688],
#  [1686, 1688],
#  [1698, 1698],
#  [1707, 1708],
#  [1707, 1708],
#  [1717, 1717],
#  [1720, 1721],
#  [1728, 1730],
#  [1728, 1730],
#  [1741, 1741],
#  [1741, 1741],
#  [1754, 1756],
#  [1767, 1767],
#  [1773, 1773],
#  [1781, 1782],
#  [1791, 1792],
#  [1797, 1798],
#  [1806, 1807],
#  [1812, 1812],
#  [1812, 1812],
#  [1819, 1820],
#  [1824, 1824],
#  [1824, 1824],
#  [1831, 1831],
#  [1844, 1845],
#  [1855, 1855],
#  [1869, 1869],
#  [1869, 1869],
#  [1890, 1890],
#  [1890, 1890],
#  [1902, 1902],
#  [1907, 1907],
#  [1907, 1907],
#  [1917, 1917],
#  [1926, 1927],
#  [1924, 1924],
#  [1931, 1931],
#  [1936, 1936],
#  [1940, 1941],
#  [1940, 1941],
#  [1959, 1960],
#  [1963, 1963],
#  [1963, 1963],
#  [1971, 1976],
#  [1993, 1993],
#  [1997, 1997],
#  [2007, 2008],
#  [2024, 2029],
#  [2024, 2024],
#  [2032, 2033],
#  [2032, 2033],
#  [2044, 2044],
#  [2052, 2054],
#  [2052, 2054],
#  [2063, 2063],
#  [2067, 2067],
#  [2071, 2071],
#  [2079, 2079],
#  [2088, 2093],
#  [2086, 2086],
#  [2098, 2098],
#  [2098, 2098],
#  [2103, 2103],
#  [2110, 2110],
#  [2121, 2121]]

# %%
def openie_feat(openieParses, sentences, corefChains):
    triplePositions = get_triple_subject_positions(openieParses, sentences)
    feature = np.zeros(len(corefChains['clusters']))

    for i, corefChain in enumerate(corefChains['clusters']):
        for mention in corefChain['mentions']:
            for position in triplePositions:
                if mention['position'] == position:
                    feature[i] += 1
                    break

    if np.std(feature) == 0:
        return np.zeros(len(corefChains['clusters']))
    
    return (feature - np.mean(feature)) / (np.std(feature))

# %%
feat = openie_feat(openieParses, sentences, corefs)

# %%
feat
# Out:
# array([ 5.30960016, -0.29680995, -0.29680995, -0.24074585,  1.94575409,
#        -0.18468174, -0.12861764, -0.29680995, -0.29680995, -0.29680995,
#        -0.18468174, -0.24074585, -0.18468174, -0.24074585, -0.12861764,
#        -0.01648944, -0.29680995, -0.29680995, -0.29680995,  0.26383106,
#        -0.24074585, -0.24074585, -0.29680995, -0.29680995, -0.24074585,
#        -0.24074585, -0.24074585, -0.24074585, -0.18468174, -0.29680995,
#        -0.29680995, -0.29680995, -0.24074585, -0.24074585])
